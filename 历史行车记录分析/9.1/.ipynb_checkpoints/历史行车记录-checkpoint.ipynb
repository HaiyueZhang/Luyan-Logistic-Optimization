# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from datetime import datetime
import numpy as np

# %%
file_path = "全部车辆-7月21日-历史轨迹.xlsx"
df1 = pd.read_excel(file_path, engine='openpyxl')
df1
# Out:
# /Users/zhanghaiyue/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        Unnamed: 0 Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0             NaN       历史轨迹                  NaN        NaN        NaN
# 1             NaN         序号                 定位时间       行驶速度       行驶里程
# 2             NaN          1  2023-07-21 10:53:38     0 km/h       0 km
# 3             NaN          2  2023-07-21 10:54:01     0 km/h       0 km
# 4             NaN          3  2023-07-21 08:00:26     1 km/h       0 km
# ...           ...        ...                  ...        ...        ...
# 13512         NaN      13511  2023-07-21 23:45:56     0 km/h   191.2 km
# 13513         NaN      13512  2023-07-21 23:48:56     0 km/h   191.2 km
# 13514         NaN      13513  2023-07-21 23:51:56     0 km/h   191.2 km
# 13515         NaN      13514  2023-07-21 23:54:56     0 km/h   191.2 km
# 13516         NaN      13515  2023-07-21 23:57:56     0 km/h   191.2 km
#
#               Unnamed: 5 Unnamed: 6 Unnamed: 7      Unnamed: 8  \
# 0                    NaN        NaN        NaN             NaN
# 1                已停留/总停留       定位信号       通讯信号            车辆状态
# 2               0秒 / 23秒        7-强       31-强  在线 / 停车 / ACC开
# 3              23秒 / 23秒        9-强       31-强  在线 / 停车 / ACC开
# 4                               6-中       31-强         在线 / 行驶
# ...                  ...        ...        ...             ...
# 13512     7时4秒 / 7时12分4秒       26-强       31-强  在线 / 停车 / ACC关
# 13513   7时3分4秒 / 7时12分4秒       26-强       31-强  在线 / 停车 / ACC关
# 13514   7时6分4秒 / 7时12分4秒       26-强       31-强  在线 / 停车 / ACC关
# 13515   7时9分4秒 / 7时12分4秒       26-强       31-强  在线 / 停车 / ACC关
# 13516  7时12分4秒 / 7时12分4秒       26-强       31-强  在线 / 停车 / ACC关
#
#                                               Unnamed: 9 Unnamed: 10  \
# 0                                                    NaN         NaN
# 1                                                   地理位置        车牌号码
# 2      福建省厦门市集美区灌口镇三社路356号;集美北大道,安仁大道-三社路交叉路口;厦门鹭燕制药有...     闽D0TL89
# 3      福建省厦门市集美区灌口镇三社路356号;集美北大道,安仁大道-三社路交叉路口;厦门鹭燕制药有...     闽D0TL89
# 4      福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,厦门市协晟工贸有限公司,厦门景联...     闽D1YX58
# ...                                                  ...         ...
# 13512  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...     闽DU5C37
# 13513  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...     闽DU5C37
# 13514  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...     闽DU5C37
# 13515  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...     闽DU5C37
# 13516  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...     闽DU5C37
#
#        Unnamed: 11    Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0              NaN            NaN         NaN         NaN         NaN
# 1             终端标识          SIM卡号        行驶方向        ACC         定位类型
# 2      18890001213  1441047914279       正北(0)           开   GPS北斗兼容模式
# 3      18890001213  1441047914279       正北(0)           开   GPS北斗兼容模式
# 4      18890000481  1441047914282     偏东(108)           开   GPS北斗兼容模式
# ...            ...            ...         ...         ...         ...
# 13512  18890001173  1441047914435       正北(0)           关   GPS北斗兼容模式
# 13513  18890001173  1441047914435       正北(0)           关   GPS北斗兼容模式
# 13514  18890001173  1441047914435       正北(0)           关   GPS北斗兼容模式
# 13515  18890001173  1441047914435       正北(0)           关   GPS北斗兼容模式
# 13516  18890001173  1441047914435       正北(0)           关   GPS北斗兼容模式
#
#       Unnamed: 16 Unnamed: 17
# 0             NaN         NaN
# 1            定位纬度        定位经度
# 2       24.601939  118.003062
# 3       24.601939  118.003062
# 4       24.601513  118.003302
# ...           ...         ...
# 13512   24.602407  118.003305
# 13513   24.602407  118.003305
# 13514   24.602407  118.003305
# 13515   24.602407  118.003305
# 13516   24.602407  118.003305
#
# [13517 rows x 18 columns]

# %%
df1 = df1.drop(columns=["Unnamed: 0"])

# Drop the first row
df1 = df1.iloc[1:]

# Set the second row as column names
df1.columns = df1.iloc[0]
df1 = df1.iloc[1:]

# Reset the index
df1.reset_index(drop=True, inplace=True)
df1
# Out:
# 1         序号                 定位时间    行驶速度      行驶里程            已停留/总停留  定位信号  \
# 0          1  2023-07-21 10:53:38  0 km/h      0 km           0秒 / 23秒   7-强
# 1          2  2023-07-21 10:54:01  0 km/h      0 km          23秒 / 23秒   9-强
# 2          3  2023-07-21 08:00:26  1 km/h      0 km                      6-中
# 3          4  2023-07-21 08:00:35  0 km/h      0 km            0秒 / 0秒   5-中
# 4          5  2023-07-21 08:00:38  4 km/h      0 km                      5-中
# ...      ...                  ...     ...       ...                ...   ...
# 13510  13511  2023-07-21 23:45:56  0 km/h  191.2 km     7时4秒 / 7时12分4秒  26-强
# 13511  13512  2023-07-21 23:48:56  0 km/h  191.2 km   7时3分4秒 / 7时12分4秒  26-强
# 13512  13513  2023-07-21 23:51:56  0 km/h  191.2 km   7时6分4秒 / 7时12分4秒  26-强
# 13513  13514  2023-07-21 23:54:56  0 km/h  191.2 km   7时9分4秒 / 7时12分4秒  26-强
# 13514  13515  2023-07-21 23:57:56  0 km/h  191.2 km  7时12分4秒 / 7时12分4秒  26-强
#
# 1      通讯信号            车辆状态  \
# 0      31-强  在线 / 停车 / ACC开
# 1      31-强  在线 / 停车 / ACC开
# 2      31-强         在线 / 行驶
# 3      31-强  在线 / 停车 / ACC开
# 4      31-强         在线 / 行驶
# ...     ...             ...
# 13510  31-强  在线 / 停车 / ACC关
# 13511  31-强  在线 / 停车 / ACC关
# 13512  31-强  在线 / 停车 / ACC关
# 13513  31-强  在线 / 停车 / ACC关
# 13514  31-强  在线 / 停车 / ACC关
#
# 1                                                   地理位置     车牌号码  \
# 0      福建省厦门市集美区灌口镇三社路356号;集美北大道,安仁大道-三社路交叉路口;厦门鹭燕制药有...  闽D0TL89
# 1      福建省厦门市集美区灌口镇三社路356号;集美北大道,安仁大道-三社路交叉路口;厦门鹭燕制药有...  闽D0TL89
# 2      福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,厦门市协晟工贸有限公司,厦门景联...  闽D1YX58
# 3      福建省厦门市集美区灌口镇安仁大道1599号;集美北大道,集美北大道-安仁大道辅路交叉路口;厦...  闽D1YX58
# 4      福建省厦门市集美区灌口镇安仁大道1599号;集美北大道,集美北大道-安仁大道辅路交叉路口;厦...  闽D1YX58
# ...                                                  ...      ...
# 13510  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...  闽DU5C37
# 13511  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...  闽DU5C37
# 13512  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...  闽DU5C37
# 13513  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...  闽DU5C37
# 13514  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...  闽DU5C37
#
# 1             终端标识          SIM卡号     行驶方向 ACC        定位类型       定位纬度  \
# 0      18890001213  1441047914279    正北(0)    开  GPS北斗兼容模式  24.601939
# 1      18890001213  1441047914279    正北(0)    开  GPS北斗兼容模式  24.601939
# 2      18890000481  1441047914282  偏东(108)    开  GPS北斗兼容模式  24.601513
# 3      18890000481  1441047914282    正北(0)    开  GPS北斗兼容模式  24.601525
# 4      18890000481  1441047914282   偏东(97)    开  GPS北斗兼容模式  24.601534
# ...            ...            ...      ...  ...        ...        ...
# 13510  18890001173  1441047914435    正北(0)    关  GPS北斗兼容模式  24.602407
# 13511  18890001173  1441047914435    正北(0)    关  GPS北斗兼容模式  24.602407
# 13512  18890001173  1441047914435    正北(0)    关  GPS北斗兼容模式  24.602407
# 13513  18890001173  1441047914435    正北(0)    关  GPS北斗兼容模式  24.602407
# 13514  18890001173  1441047914435    正北(0)    关  GPS北斗兼容模式  24.602407
#
# 1            定位经度
# 0      118.003062
# 1      118.003062
# 2      118.003302
# 3      118.003282
# 4      118.003292
# ...           ...
# 13510  118.003305
# 13511  118.003305
# 13512  118.003305
# 13513  118.003305
# 13514  118.003305
#
# [13515 rows x 17 columns]

# %%
# Assuming df1 is your dataframe

# List of columns to be dropped
columns_to_drop = ["定位信号", "通讯信号", "终端标识", "SIM卡号", "ACC ", "定位类型"]

# Drop the columns
df1 = df1.drop(columns=columns_to_drop)

# Display the modified dataframe
df1
# Out:
# 1         序号                 定位时间    行驶速度      行驶里程            已停留/总停留  \
# 0          1  2023-07-21 10:53:38  0 km/h      0 km           0秒 / 23秒
# 1          2  2023-07-21 10:54:01  0 km/h      0 km          23秒 / 23秒
# 2          3  2023-07-21 08:00:26  1 km/h      0 km
# 3          4  2023-07-21 08:00:35  0 km/h      0 km            0秒 / 0秒
# 4          5  2023-07-21 08:00:38  4 km/h      0 km
# ...      ...                  ...     ...       ...                ...
# 13510  13511  2023-07-21 23:45:56  0 km/h  191.2 km     7时4秒 / 7时12分4秒
# 13511  13512  2023-07-21 23:48:56  0 km/h  191.2 km   7时3分4秒 / 7时12分4秒
# 13512  13513  2023-07-21 23:51:56  0 km/h  191.2 km   7时6分4秒 / 7时12分4秒
# 13513  13514  2023-07-21 23:54:56  0 km/h  191.2 km   7时9分4秒 / 7时12分4秒
# 13514  13515  2023-07-21 23:57:56  0 km/h  191.2 km  7时12分4秒 / 7时12分4秒
#
# 1                车辆状态                                               地理位置  \
# 0      在线 / 停车 / ACC开  福建省厦门市集美区灌口镇三社路356号;集美北大道,安仁大道-三社路交叉路口;厦门鹭燕制药有...
# 1      在线 / 停车 / ACC开  福建省厦门市集美区灌口镇三社路356号;集美北大道,安仁大道-三社路交叉路口;厦门鹭燕制药有...
# 2             在线 / 行驶  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,厦门市协晟工贸有限公司,厦门景联...
# 3      在线 / 停车 / ACC开  福建省厦门市集美区灌口镇安仁大道1599号;集美北大道,集美北大道-安仁大道辅路交叉路口;厦...
# 4             在线 / 行驶  福建省厦门市集美区灌口镇安仁大道1599号;集美北大道,集美北大道-安仁大道辅路交叉路口;厦...
# ...               ...                                                ...
# 13510  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...
# 13511  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...
# 13512  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...
# 13513  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...
# 13514  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇三社路126号;集美北大道,安仁大道-三社路交叉路口;格林后整体家居...
#
# 1         车牌号码     行驶方向       定位纬度        定位经度
# 0      闽D0TL89    正北(0)  24.601939  118.003062
# 1      闽D0TL89    正北(0)  24.601939  118.003062
# 2      闽D1YX58  偏东(108)  24.601513  118.003302
# 3      闽D1YX58    正北(0)  24.601525  118.003282
# 4      闽D1YX58   偏东(97)  24.601534  118.003292
# ...        ...      ...        ...         ...
# 13510  闽DU5C37    正北(0)  24.602407  118.003305
# 13511  闽DU5C37    正北(0)  24.602407  118.003305
# 13512  闽DU5C37    正北(0)  24.602407  118.003305
# 13513  闽DU5C37    正北(0)  24.602407  118.003305
# 13514  闽DU5C37    正北(0)  24.602407  118.003305
#
# [13515 rows x 11 columns]

# %%
df1['location'] = df1['定位经度'].astype(str) + "," + df1['定位纬度'].astype(str)
df1 = df1.drop(columns = ['定位经度', '定位纬度'])

# %%
df1.to_csv('历史轨迹7.21.csv', index=False, encoding='utf-8-sig')

# %%
df1 = pd.read_csv('历史轨迹9.1.csv')
df2 = pd.read_csv('Xiamen_Unique_locations最新有仓库.csv')
df3 = pd.read_csv('7-9月派送信息.csv')
df4 = pd.read_csv('9.1-12连续停靠点drop.csv')

# %%
df3['SIGNDATE'] = pd.to_datetime(df3['SIGNDATE'])
df3['DISPATCHDATE'] = pd.to_datetime(df3['DISPATCHDATE'])

# Define the start and end dates for the interval
start_date = datetime(2023, 9, 1).date()
end_date = datetime(2023, 9, 12).date()

# Select rows where both 'SIGNDATE' and 'DISPATCHDATE' are within the specified interval
df_interval = df3[(df3['SIGNDATE'].dt.date >= start_date) & (df3['SIGNDATE'].dt.date <= end_date) &
                  (df3['DISPATCHDATE'].dt.date >= start_date) & (df3['DISPATCHDATE'].dt.date <= end_date)]

df_interval = df_interval.drop_duplicates(subset='combine')
df_interval
# Out:
#        ROUTEID  TRANSID                         SENDPOS              CREDATE  \
# 32          11      638                         卫生院总院药房  2023-09-12 14:03:00
# 351          6     1017                         中医院门诊药房  2023-09-12 14:06:00
# 605          6      194                     厦门市湖里区妇幼保健所  2023-09-07 13:35:00
# 623          1     1905                           市妇幼药库  2023-09-03 15:27:00
# 787          8      103                厦门集美侨英街道社区卫生服务中心  2023-09-06 13:51:00
# ...        ...      ...                             ...                  ...
# 37204        8  3136487        厦门市同安区滨富二里19-110、19-111号  2023-09-04 22:49:00
# 37288       11  2239205               厦门市海沧区东孚镇过坂北里190号  2023-09-05 22:47:00
# 37303        8  2238711           厦门市同安区西柯镇官浔村西官浔里80-3号  2023-09-04 22:49:00
# 37357        8  2239034  厦门市集美区后溪英村平阳里小区1-1#楼一楼农贸市场3号店面  2023-09-10 14:08:00
# 37420        5  2242151           （燕来福）厦门湖里瑞来春中医门诊部有限公司  2023-09-11 13:56:00
#
#              DISPATCHDATE            SIGNDATE        DATE   Xiamen.经度  \
# 32    2023-09-12 17:20:00 2023-09-12 17:20:00  2023-09-12  117.997091
# 351   2023-09-12 16:53:00 2023-09-12 16:54:00  2023-09-12  118.140663
# 605   2023-09-07 16:23:00 2023-09-07 16:26:00  2023-09-07  118.150087
# 623   2023-09-04 13:38:00 2023-09-04 13:38:00  2023-09-03  118.081864
# 787   2023-09-07 11:06:00 2023-09-07 11:06:00  2023-09-06  118.106309
# ...                   ...                 ...         ...         ...
# 37204 2023-09-05 11:20:00 2023-09-05 11:20:00  2023-09-04  118.152149
# 37288 2023-09-06 11:30:00 2023-09-06 11:31:00  2023-09-05  117.943625
# 37303 2023-09-05 11:19:00 2023-09-05 11:19:00  2023-09-04  118.150068
# 37357 2023-09-11 11:26:00 2023-09-11 11:26:00  2023-09-10  118.092545
# 37420 2023-09-11 17:55:00 2023-09-11 17:55:00  2023-09-11  118.146874
#
#        Xiamen.纬度               combine   longitude   latitude
# 32     24.603403  117.997091,24.603403  117.997091  24.603403
# 351    24.500073  118.140663,24.500073  118.140663  24.500073
# 605    24.511449  118.150087,24.511449  118.150087  24.511449
# 623    24.450523  118.081864,24.450523  118.081864  24.450523
# 787    24.595218  118.106309,24.595218  118.106309  24.595218
# ...          ...                   ...         ...        ...
# 37204  24.722747  118.152149,24.722747  118.152149  24.722747
# 37288  24.566692  117.943625,24.566692  117.943625  24.566692
# 37303  24.654921  118.150068,24.654921  118.150068  24.654921
# 37357  24.615475  118.092545,24.615475  118.092545  24.615475
# 37420  24.492573  118.146874,24.492573  118.146874  24.492573
#
# [293 rows x 12 columns]

# %%
df1
# Out:
#           序号                 定位时间    行驶速度       行驶里程               已停留/总停留  \
# 0          1  2023-09-01 00:01:21  0 km/h       0 km         0秒 / 6时56分47秒
# 1          2  2023-09-01 00:04:21  0 km/h       0 km         3分 / 6时56分47秒
# 2          3  2023-09-01 00:07:21  0 km/h       0 km         6分 / 6时56分47秒
# 3          4  2023-09-01 00:10:21  0 km/h       0 km         9分 / 6时56分47秒
# 4          5  2023-09-01 00:13:21  0 km/h       0 km        12分 / 6时56分47秒
# ...      ...                  ...     ...        ...                   ...
# 59995  59996  2023-09-12 18:44:41  0 km/h  861.13 km  1时41分15秒 / 14时53分47秒
# 59996  59997  2023-09-12 18:46:52  0 km/h  861.13 km  1时43分26秒 / 14时53分47秒
# 59997  59998  2023-09-12 18:48:52  0 km/h  861.13 km  1时45分26秒 / 14时53分47秒
# 59998  59999  2023-09-12 18:50:52  0 km/h  861.13 km  1时47分26秒 / 14时53分47秒
# 59999  60000  2023-09-12 18:53:03  0 km/h  861.13 km  1时49分37秒 / 14时53分47秒
#
#                  车辆状态                                               地理位置  \
# 0      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# 1      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# 2      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# 3      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# 4      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# ...               ...                                                ...
# 59995  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
# 59996  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
# 59997  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
# 59998  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
# 59999  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
#
#           车牌号码   行驶方向              location   longitude   latitude
# 0      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318
# 1      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318
# 2      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318
# 3      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318
# 4      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318
# ...        ...    ...                   ...         ...        ...
# 59995  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012
# 59996  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012
# 59997  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012
# 59998  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012
# 59999  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012
#
# [60000 rows x 12 columns]

# %%
# Split 'location' into 'longitude' and 'latitude' for df1
df1[['longitude', 'latitude']] = df1['location'].str.split(',', expand=True).astype(float)

# Do the same for df9_1
df_interval[['longitude', 'latitude']] = df_interval['combine'].str.split(',', expand=True).astype(float)

# Plotting with a larger figure size, e.g., 15 inches by 10 inches
fig, ax = plt.subplots(figsize=(13, 10))

# Generate a color for each '车牌号码' group in df1
colors = plt.cm.jet(np.linspace(0, 1, df1['车牌号码'].nunique()))

# Group by '车牌号码' and plot for df1
for (license_plate), group_data in df1.groupby('车牌号码'):
    ax.scatter(group_data['longitude'], group_data['latitude'], label=license_plate, s=10)

# Plot data from df3, using a different color and/or marker
# You may choose a specific color or marker for df9_1 to differentiate
ax.scatter(df_interval['longitude'], df_interval['latitude'], color='red', marker='^', label='df_interval', s=10)

# Define the range for the rectangle
long_min, long_max = 117.882223, 118.373857
lat_min, lat_max = 24.41, 24.905

# Create a Rectangle patch
rect = patches.Rectangle((long_min, lat_min), long_max - long_min, lat_max - lat_min,
                         linewidth=1, edgecolor='r', facecolor='none')

# Add the rectangle to the plot
ax.add_patch(rect)

# Optionally set a grid
ax.grid(True)

# Optionally add a legend outside of the plot
ax.legend(title='车牌号码', bbox_to_anchor=(1.05, 1), loc='upper left')

# Set labels for the axes
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Set title for the plot
ax.set_title('Locations by 车牌号码 with Highlighted Area')

# Show the plot
plt.show()
# Out:
# /Users/zhanghaiyue/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36710 (\N{CJK UNIFIED IDEOGRAPH-8F66}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/zhanghaiyue/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 29260 (\N{CJK UNIFIED IDEOGRAPH-724C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/zhanghaiyue/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21495 (\N{CJK UNIFIED IDEOGRAPH-53F7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/zhanghaiyue/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30721 (\N{CJK UNIFIED IDEOGRAPH-7801}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/zhanghaiyue/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38397 (\N{CJK UNIFIED IDEOGRAPH-95FD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Remove rows where "已停留/总停留" is empty or just has "/"
df1_non_empty = df1[df1['已停留/总停留'].astype(str).str.strip().str.match(r'.+/.+')]

# Find the difference between consecutive "序号" values
df1_non_empty['diff'] = df1_non_empty['序号'].diff().fillna(1)

# A sequence starts whenever the difference is not equal to 1
df1_non_empty['sequence'] = df1_non_empty['diff'].ne(1).cumsum()

# Group by 'sequence' and compute the sequence count
df1_non_empty['sequence_count'] = df1_non_empty.groupby('sequence').cumcount() + 1

# Filter sequences where the maximum 'sequence_count' is at least 4
sequences_with_min_length = df1_non_empty.groupby('sequence')['sequence_count'].transform('max') >= 4

# Apply this filter to the DataFrame
df1_filtered = df1_non_empty[sequences_with_min_length]

df1_filtered
# Out:
# /var/folders/3m/d1t5bhcx41n2gcv2znb8f6c40000gn/T/ipykernel_92181/868189636.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_non_empty['diff'] = df1_non_empty['序号'].diff().fillna(1)
# /var/folders/3m/d1t5bhcx41n2gcv2znb8f6c40000gn/T/ipykernel_92181/868189636.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_non_empty['sequence'] = df1_non_empty['diff'].ne(1).cumsum()
# /var/folders/3m/d1t5bhcx41n2gcv2znb8f6c40000gn/T/ipykernel_92181/868189636.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_non_empty['sequence_count'] = df1_non_empty.groupby('sequence').cumcount() + 1
#           序号                 定位时间    行驶速度       行驶里程               已停留/总停留  \
# 0          1  2023-09-01 00:01:21  0 km/h       0 km         0秒 / 6时56分47秒
# 1          2  2023-09-01 00:04:21  0 km/h       0 km         3分 / 6时56分47秒
# 2          3  2023-09-01 00:07:21  0 km/h       0 km         6分 / 6时56分47秒
# 3          4  2023-09-01 00:10:21  0 km/h       0 km         9分 / 6时56分47秒
# 4          5  2023-09-01 00:13:21  0 km/h       0 km        12分 / 6时56分47秒
# ...      ...                  ...     ...        ...                   ...
# 59995  59996  2023-09-12 18:44:41  0 km/h  861.13 km  1时41分15秒 / 14时53分47秒
# 59996  59997  2023-09-12 18:46:52  0 km/h  861.13 km  1时43分26秒 / 14时53分47秒
# 59997  59998  2023-09-12 18:48:52  0 km/h  861.13 km  1时45分26秒 / 14时53分47秒
# 59998  59999  2023-09-12 18:50:52  0 km/h  861.13 km  1时47分26秒 / 14时53分47秒
# 59999  60000  2023-09-12 18:53:03  0 km/h  861.13 km  1时49分37秒 / 14时53分47秒
#
#                  车辆状态                                               地理位置  \
# 0      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# 1      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# 2      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# 3      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# 4      在线 / 停车 / ACC关                     福建省厦门市湖里区禾山街道;;向上幼儿园,安达公寓,闲寓筱筑
# ...               ...                                                ...
# 59995  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
# 59996  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
# 59997  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
# 59998  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
# 59999  在线 / 停车 / ACC关  福建省厦门市集美区灌口镇;集美北大道;厦门鹭燕制药有限公司,爱觉管家式长租公寓,集美国投安仁产业园
#
#           车牌号码   行驶方向              location   longitude   latitude  diff  \
# 0      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318   1.0
# 1      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318   1.0
# 2      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318   1.0
# 3      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318   1.0
# 4      闽D0TL89  正北(0)  118.157613,24.531318  118.157613  24.531318   1.0
# ...        ...    ...                   ...         ...        ...   ...
# 59995  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012   1.0
# 59996  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012   1.0
# 59997  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012   1.0
# 59998  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012   1.0
# 59999  闽D1YX58  正北(0)  118.003397,24.602012  118.003397  24.602012   1.0
#
#        sequence  sequence_count
# 0             0               1
# 1             0               2
# 2             0               3
# 3             0               4
# 4             0               5
# ...         ...             ...
# 59995      1969              52
# 59996      1969              53
# 59997      1969              54
# 59998      1969              55
# 59999      1969              56
#
# [17410 rows x 15 columns]

# %%
df1_filtered.to_csv('9.1-12连续停靠点drop.csv', index=False, encoding='utf-8-sig')

# %%
df1_filtered = pd.read_csv('9.1-12连续停靠点drop.csv')
# Function to convert the time format "X时Y分Z秒" into seconds
def convert_to_seconds(time_str):
    if pd.notna(time_str):  # Check if the time_str is not NaN
        # Initialize days, hours, minutes, and seconds to 0
        days, hours, minutes, seconds = 0, 0, 0, 0

        # Check if '天' is present
        if '天' in time_str:
            parts = time_str.split('天')
            days = int(parts[0])
            time_str = parts[1]  # Remaining part after '天'

        # Check if '时' is present
        if '时' in time_str:
            parts = time_str.split('时')
            hours = int(parts[0])
            time_str = parts[1]  # Remaining part after '时'
        
        # Check if '分' is present
        if '分' in time_str:
            parts = time_str.split('分')
            minutes = int(parts[0])
            # Check if there's a second part after '分' (for seconds)
            if len(parts) > 1 and parts[1] != '':
                seconds = int(parts[1].rstrip('秒'))
        else:
            # If '分' is not present, then we only have seconds
            seconds = int(time_str.rstrip('秒'))
            
        return days * 86400 + hours * 3600 + minutes * 60 + seconds
    else:
        return 0 # Return 0 if the input is NaN

# Extract the total duration part (after the slash) for each group's first row
# Split by ' / ' (space, slash, space) and get the second part [1]
df1_filtered['total_duration'] = df1_filtered.groupby('sequence')['已停留/总停留'].transform('first').str.split(' / ').str[1]

# Convert the total duration to seconds using the conversion function
df1_filtered['total_duration_seconds'] = df1_filtered['total_duration'].apply(convert_to_seconds)

# Group by 'sequence' and calculate the average duration in seconds for each group
df_group_avg_duration = df1_filtered.groupby('sequence')['total_duration_seconds'].mean().reset_index()

# Rename the columns for clarity
df_group_avg_duration.columns = ['sequence', 'average_duration_seconds']
df_group_avg_duration
# Out:
#      sequence  average_duration_seconds
# 0           0                   25007.0
# 1           5                    2535.0
# 2           8                     123.0
# 3           9                     119.0
# 4          12                     211.0
# ..        ...                       ...
# 612      1949                     173.0
# 613      1950                     150.0
# 614      1951                      90.0
# 615      1967                      69.0
# 616      1969                   53627.0
#
# [617 rows x 2 columns]

# %%
# Filter the dataframe where 'average_duration_seconds' is less than 2400
filtered_df = df_group_avg_duration[df_group_avg_duration['average_duration_seconds'] < 3600]

# Calculate the sum of 'average_duration_seconds' for the filtered rows
sum_of_durations = filtered_df['average_duration_seconds'].sum()

# Calculate the count of the filtered rows
count_of_durations = len(filtered_df)

# Calculate the average duration for the filtered rows
# Here we check if count_of_durations is not zero to avoid division by zero
average_duration = sum_of_durations / count_of_durations if count_of_durations else 0

print(f"Average Duration for filtered groups: {average_duration} seconds")
filtered_df
# Out:
# Average Duration for filtered groups: 349.4572953736655 seconds
#      sequence  average_duration_seconds
# 1           5                    2535.0
# 2           8                     123.0
# 3           9                     119.0
# 4          12                     211.0
# 5          14                     120.0
# ..        ...                       ...
# 611      1927                     178.0
# 612      1949                     173.0
# 613      1950                     150.0
# 614      1951                      90.0
# 615      1967                      69.0
#
# [562 rows x 2 columns]

# %%
# Split 'location' into 'longitude' and 'latitude' for df1
df1[['longitude', 'latitude']] = df1['location'].str.split(',', expand=True).astype(float)

# Do the same for df9_1
df_interval[['longitude', 'latitude']] = df_interval['combine'].str.split(',', expand=True).astype(float)

# Do the same for df4 and drop duplicates
df4[['longitude', 'latitude']] = df4['location'].str.split(',', expand=True).astype(float)
df4 = df4.drop_duplicates(subset=['longitude', 'latitude'])

# Plotting with a larger figure size, e.g., 15 inches by 10 inches
fig, ax = plt.subplots(figsize=(13, 10))

# Generate a color for each '车牌号码' group in df1
colors = plt.cm.jet(np.linspace(0, 1, df1['车牌号码'].nunique()))

# Group by '车牌号码' and plot for df1
for (license_plate), group_data in df1.groupby('车牌号码'):
    ax.scatter(group_data['longitude'], group_data['latitude'], label=license_plate, s=10)

# Plot data from df3, using a different color and/or marker
# You may choose a specific color or marker for df9_1 to differentiate
ax.scatter(df_interval['longitude'], df_interval['latitude'], color='red', marker='^', label='df_interval', s=10)

# Plot unique data from df4, using blue color for dots
ax.scatter(df4['longitude'], df4['latitude'], color='black', label='df4 delivery stop locations', s=15)

# Define the range for the rectangle
long_min, long_max = 117.882223, 118.373857
lat_min, lat_max = 24.41, 24.905

# Create a Rectangle patch
rect = patches.Rectangle((long_min, lat_min), long_max - long_min, lat_max - lat_min,
                         linewidth=1, edgecolor='r', facecolor='none')

# Add the rectangle to the plot
ax.add_patch(rect)

# Optionally set a grid
ax.grid(True)

# Optionally add a legend outside of the plot
ax.legend(title='车牌号码', bbox_to_anchor=(1.05, 1), loc='upper left')

# Set labels for the axes
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Set title for the plot
ax.set_title('Locations by 车牌号码 with Highlighted Area')

# Show the plot
plt.show()

# %% [markdown]
# ### 200m = 0.001796 degree in longitude or lattitude
# ### 100m = 0.000898 degree
# ### 50m = 0.000448 degree
# ### 25m = 0.000225 degree
# ### 22m = 0.0002 degree

# %%
# Assuming df1 and df2 are already loaded
# Decompose the 'location' column in df1 and df2 into separate 'longitude' and 'latitude' columns
df1['longitude'] = df1['location'].str.split(',').str[0].astype(float)
df1['latitude'] = df1['location'].str.split(',').str[1].astype(float)

df2['longitude'] = df2['location'].str.split(',').str[0].astype(float)
df2['latitude'] = df2['location'].str.split(',').str[1].astype(float)

# Define the range
delta = 0.000898

# Create the bounds for df2
df2['longitude_min'] = df2['longitude'] - delta
df2['longitude_max'] = df2['longitude'] + delta
df2['latitude_min'] = df2['latitude'] - delta
df2['latitude_max'] = df2['latitude'] + delta

# Check if each df1 location is within the square bounds of any df2 location
def check_within_bounds(row):
    matching_rows = df2[
        (df2['longitude_min'] <= row['longitude']) & 
        (df2['longitude_max'] >= row['longitude']) & 
        (df2['latitude_min'] <= row['latitude']) & 
        (df2['latitude_max'] >= row['latitude'])
    ]
    if not matching_rows.empty:
        return matching_rows.iloc[0][['TRANSID', 'INCEPTADDR']]
    else:
        return pd.Series([None, None], index=['TRANSID', 'INCEPTADDR'])

results = df1.apply(check_within_bounds, axis=1)
df1['TRANSID'] = results['TRANSID']
df1['INCEPTADDR'] = results['INCEPTADDR']

# Drop the extra columns we added
df1 = df1.drop(['longitude', 'latitude'], axis=1)
# Drop NA Inceptaddr
filtered_df = df1[df1['INCEPTADDR'].notna()]
filtered_df
# Out:
#           序号                 定位时间     行驶速度       行驶里程  已停留/总停留  \
# 210      211  2023-09-01 07:07:58  42 km/h    4.07 km
# 211      212  2023-09-01 07:08:11  39 km/h    4.23 km
# 252      253  2023-09-01 07:18:53  58 km/h   14.13 km
# 255      256  2023-09-01 07:19:58  23 km/h   14.59 km
# 284      285  2023-09-01 07:27:07  20 km/h   20.42 km
# ...      ...                  ...      ...        ...      ...
# 59930  59931  2023-09-12 16:57:30  12 km/h  861.02 km
# 59931  59932  2023-09-12 16:57:32  12 km/h  861.02 km
# 59932  59933  2023-09-12 16:57:44   0 km/h  861.03 km  0秒 / 0秒
# 59933  59934  2023-09-12 16:58:08   5 km/h  861.04 km
# 59934  59935  2023-09-12 16:58:14   1 km/h  861.05 km
#
#                  车辆状态                                               地理位置  \
# 210           在线 / 行驶     福建省厦门市湖里区殿前街道;枋钟路辅路;空港云立方,厦门紫金科技大楼,紫金宾馆(翔云三路店)
# 211           在线 / 行驶  福建省厦门市湖里区殿前街道枋钟路1679号;枋钟路,火炬北路-枋钟路交叉路口;鲤正记金丝牛肉...
# 252           在线 / 行驶           福建省厦门市集美区杏林街道;杏前路18-19号;诚礼楼,华舒酒店,厦门市杏苑小区
# 255           在线 / 行驶     福建省厦门市集美区杏林街道;G319(杏前路);锦秀园建材,厦杏大厦,厦门市公安局集美区分局
# 284           在线 / 行驶  福建省厦门市集美区灌口镇;集美北大道1030号;厦门燕来福制药有限公司-东北门,视捷自动化科...
# ...               ...                                                ...
# 59930         在线 / 行驶  福建省厦门市集美区灌口镇三社路126号;集美北大道,315乡道-三社路交叉路口;格林后整体家...
# 59931         在线 / 行驶  福建省厦门市集美区灌口镇三社路126号;集美北大道,315乡道-三社路交叉路口;格林后整体家...
# 59932  在线 / 停车 / ACC开  福建省厦门市集美区灌口镇三社路126号;集美北大道,315乡道-三社路交叉路口;格林后整体家...
# 59933         在线 / 行驶  福建省厦门市集美区灌口镇三社路126号;集美北大道,315乡道-三社路交叉路口;格林后整体家...
# 59934         在线 / 行驶  福建省厦门市集美区灌口镇三社路126号;集美北大道,315乡道-三社路交叉路口;格林后整体家...
#
#           车牌号码     行驶方向              location    TRANSID  \
# 210    闽D0TL89  西南(228)  118.128105,24.531552      568.0
# 211    闽D0TL89  西南(241)  118.126843,24.530701      568.0
# 252    闽D0TL89  偏西(276)  118.050001,24.573475  1087903.0
# 255    闽D0TL89  偏西(276)   118.04549,24.573939      100.0
# 284    闽D0TL89   东北(31)   118.00354,24.601637  2773991.0
# ...        ...      ...                   ...        ...
# 59930  闽D1YX58    偏北(3)   118.003684,24.60231  2773991.0
# 59931  闽D1YX58   东北(55)  118.003711,24.602362  2773991.0
# 59932  闽D1YX58    正北(0)  118.003779,24.602418  2773991.0
# 59933  闽D1YX58  偏南(174)   118.00371,24.602366  2773991.0
# 59934  闽D1YX58  东南(156)   118.00369,24.602326  2773991.0
#
#                      INCEPTADDR
# 210             湖里区殿前街道翔云一路100号
# 211             湖里区殿前街道翔云一路100号
# 252         厦门市集美区杏林街道内林村洪厝135号
# 255                   集美区杏北路25号
# 284    厦门市集美区安仁里7号104-2室、104-3室
# ...                         ...
# 59930  厦门市集美区安仁里7号104-2室、104-3室
# 59931  厦门市集美区安仁里7号104-2室、104-3室
# 59932  厦门市集美区安仁里7号104-2室、104-3室
# 59933  厦门市集美区安仁里7号104-2室、104-3室
# 59934  厦门市集美区安仁里7号104-2室、104-3室
#
# [11581 rows x 12 columns]

# %%
# Save filtered_df to csv file
filtered_df.to_csv('历史轨迹9.1-all_200m.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# #### delta = 0.0002: 818 results
# #### delta = 0.000225: 1061 results
# #### delta = 0.000448: 3774 results
# #### delta = 0.000898: 11581 results

# %%
# Filter df1 to only include rows where "车辆状态" is "在线 / 停车 / ACC开"
df1 = df1[(df1['车辆状态'] == "在线 / 停车 / ACC开")]

# Assuming df1 and df2 are already loaded
# Decompose the 'location' column in df1 and df2 into separate 'longitude' and 'latitude' columns
df1['longitude'] = df1['location'].str.split(',').str[0].astype(float)
df1['latitude'] = df1['location'].str.split(',').str[1].astype(float)

df2['longitude'] = df2['location'].str.split(',').str[0].astype(float)
df2['latitude'] = df2['location'].str.split(',').str[1].astype(float)

# Define the range
delta = 0.000448

# Create the bounds for df2
df2['longitude_min'] = df2['longitude'] - delta
df2['longitude_max'] = df2['longitude'] + delta
df2['latitude_min'] = df2['latitude'] - delta
df2['latitude_max'] = df2['latitude'] + delta

# Check if each df1 location is within the square bounds of any df2 location
def check_within_bounds(row):
    matching_rows = df2[
        (df2['longitude_min'] <= row['longitude']) & 
        (df2['longitude_max'] >= row['longitude']) & 
        (df2['latitude_min'] <= row['latitude']) & 
        (df2['latitude_max'] >= row['latitude'])
    ]
    if not matching_rows.empty:
        return matching_rows.iloc[0][['TRANSID', 'INCEPTADDR']]
    else:
        return pd.Series([None, None], index=['TRANSID', 'INCEPTADDR'])

results = df1.apply(check_within_bounds, axis=1)
df1['TRANSID'] = results['TRANSID']
df1['INCEPTADDR'] = results['INCEPTADDR']

# Drop the extra columns we added
df1 = df1.drop(['longitude', 'latitude'], axis=1)
filtered_df = df1[df1['INCEPTADDR'].notna()]
filtered_df
# Out:
#           序号                 定位时间    行驶速度       行驶里程        已停留/总停留  \
# 620      621  2023-09-01 09:16:05  0 km/h    47.4 km        0秒 / 0秒
# 730      731  2023-09-01 09:33:04  0 km/h    50.2 km       0秒 / 30秒
# 731      732  2023-09-01 09:33:34  0 km/h    50.2 km      30秒 / 30秒
# 872      873  2023-09-01 10:00:31  0 km/h   53.17 km       0秒 / 59秒
# 873      874  2023-09-01 10:01:00  0 km/h   53.17 km      29秒 / 59秒
# ...      ...                  ...     ...        ...            ...
# 59449  59450  2023-09-12 11:34:19  0 km/h  828.51 km  1分30秒 / 1分30秒
# 59651  59652  2023-09-12 14:34:58  0 km/h   843.7 km        0秒 / 0秒
# 59663  59664  2023-09-12 14:35:58  0 km/h  843.74 km       0秒 / 59秒
# 59664  59665  2023-09-12 14:36:28  0 km/h  843.74 km      30秒 / 59秒
# 59665  59666  2023-09-12 14:36:57  0 km/h  843.74 km      59秒 / 59秒
#
#                  车辆状态                                               地理位置  \
# 620    在线 / 停车 / ACC开                     福建省厦门市思明区;洪莲里22号;洪莲里,聚丰新城,联丰新城
# 730    在线 / 停车 / ACC开          福建省厦门市思明区莲前街道;田厝路7号;前埔北区二里,庄总·云聚智慧社区,国贸新城
# 731    在线 / 停车 / ACC开          福建省厦门市思明区莲前街道;田厝路7号;前埔北区二里,庄总·云聚智慧社区,国贸新城
# 872    在线 / 停车 / ACC开     福建省厦门市思明区;前埔东路598号;岭兜小区(中区),中共福建光电有限公司支部,福光工业园
# 873    在线 / 停车 / ACC开     福建省厦门市思明区;前埔东路598号;岭兜小区(中区),中共福建光电有限公司支部,福光工业园
# ...               ...                                                ...
# 59449  在线 / 停车 / ACC开  福建省厦门市集美区灌口镇;集美北大道788号-之18区;江淮轻卡,厦门迅闽车辆销售服务有限公...
# 59651  在线 / 停车 / ACC开  福建省厦门市集美区侨英街道;印斗北路,印斗北路-信毅路交叉路口;厦门医学院附属第二医院,福建...
# 59663  在线 / 停车 / ACC开  福建省厦门市集美区侨英街道;印斗北路,印斗北路-信毅路交叉路口;厦门医学院附属第二医院,福建...
# 59664  在线 / 停车 / ACC开  福建省厦门市集美区侨英街道;印斗北路,印斗北路-信毅路交叉路口;厦门医学院附属第二医院,福建...
# 59665  在线 / 停车 / ACC开  福建省厦门市集美区侨英街道;印斗北路,印斗北路-信毅路交叉路口;厦门医学院附属第二医院,福建...
#
#           车牌号码   行驶方向              location    TRANSID  \
# 620    闽D0TL89  正北(0)   118.155633,24.48001  2243658.0
# 730    闽D0TL89  正北(0)  118.166637,24.476225      761.0
# 731    闽D0TL89  正北(0)  118.166637,24.476225      761.0
# 872    闽D0TL89  正北(0)   118.174227,24.48246  2229990.0
# 873    闽D0TL89  正北(0)   118.174227,24.48246  2229990.0
# ...        ...    ...                   ...        ...
# 59449  闽D1YX58  正北(0)   118.00302,24.598892  2242363.0
# 59651  闽D1YX58  正北(0)   118.099853,24.58699  2244730.0
# 59663  闽D1YX58  正北(0)  118.099868,24.586968  2244730.0
# 59664  闽D1YX58  正北(0)  118.099868,24.586968  2244730.0
# 59665  闽D1YX58  正北(0)  118.099868,24.586968  2244730.0
#
#                                               INCEPTADDR
# 620                                      厦门市思明区洪莲中路42号店面
# 730                                             前埔西路295号
# 731                                             前埔西路295号
# 872                  厦门市思明区前埔路506-508号“国企广场”A栋14层03.05单元
# 873                  厦门市思明区前埔路506-508号“国企广场”A栋14层03.05单元
# ...                                                  ...
# 59449  1.除医疗用毒性药品（中药饮片）外委托鹭燕医药股份有限公司【仓库地址：厦门市集美区灌南工业区...
# 59651                            厦门市集美区侨英街道孙厝乐安东里28-102号
# 59663                            厦门市集美区侨英街道孙厝乐安东里28-102号
# 59664                            厦门市集美区侨英街道孙厝乐安东里28-102号
# 59665                            厦门市集美区侨英街道孙厝乐安东里28-102号
#
# [500 rows x 12 columns]

# %%
# Save filtered_df to csv file
filtered_df.to_csv('历史轨迹9.1-停车点100m.csv', index=False, encoding='utf-8-sig')

# %%
# Work on a copy to avoid SettingWithCopyWarning
filtered_df = pd.read_csv("历史轨迹9.1-停车点100m.csv")

# Convert "定位时间" column to datetime
filtered_df['定位时间'] = pd.to_datetime(filtered_df['定位时间'])

# Extract numerical value from "行驶里程" and convert it to a float
filtered_df['行驶里程'] = filtered_df['行驶里程'].str.extract('(\d+\.\d+)').astype(float)

# Compute the difference for "行驶里程" and "定位时间"
filtered_df['distance'] = filtered_df['行驶里程'].diff().fillna(0) * 1000  # Convert from km to m for the difference
filtered_df['duration'] = filtered_df['定位时间'].diff().fillna(pd.Timedelta(seconds=0)).dt.total_seconds()

# For the first row, set "distance" and "duration" to 0
filtered_df.iloc[0, filtered_df.columns.get_loc('distance')] = 0
filtered_df.iloc[0, filtered_df.columns.get_loc('duration')] = 0

# Unique for TRANSID
filtered_df = filtered_df.drop_duplicates(subset='TRANSID', keep='first').reset_index(drop=True)

filtered_df
# Out:
#        序号                定位时间    行驶速度    行驶里程   已停留/总停留            车辆状态  \
# 0     621 2023-09-01 09:16:05  0 km/h   47.40   0秒 / 0秒  在线 / 停车 / ACC开
# 1     731 2023-09-01 09:33:04  0 km/h   50.20  0秒 / 30秒  在线 / 停车 / ACC开
# 2     873 2023-09-01 10:00:31  0 km/h   53.17  0秒 / 59秒  在线 / 停车 / ACC开
# 3     991 2023-09-01 10:20:30  0 km/h   58.71   0秒 / 0秒  在线 / 停车 / ACC开
# 4     993 2023-09-01 10:21:00  0 km/h   58.72   0秒 / 1分  在线 / 停车 / ACC开
# ..    ...                 ...     ...     ...       ...             ...
# 85  54008 2023-09-05 09:53:52  0 km/h  260.49   0秒 / 1分  在线 / 停车 / ACC开
# 86  54409 2023-09-05 14:32:20  0 km/h  314.90   0秒 / 0秒  在线 / 停车 / ACC开
# 87  54753 2023-09-06 08:42:16  0 km/h  351.01   0秒 / 0秒  在线 / 停车 / ACC开
# 88  59201 2023-09-12 08:58:36  0 km/h  800.61  0秒 / 30秒  在线 / 停车 / ACC开
# 89  59652 2023-09-12 14:34:58  0 km/h  843.70   0秒 / 0秒  在线 / 停车 / ACC开
#
#                                                  地理位置     车牌号码   行驶方向  \
# 0                      福建省厦门市思明区;洪莲里22号;洪莲里,聚丰新城,联丰新城  闽D0TL89  正北(0)
# 1           福建省厦门市思明区莲前街道;田厝路7号;前埔北区二里,庄总·云聚智慧社区,国贸新城  闽D0TL89  正北(0)
# 2      福建省厦门市思明区;前埔东路598号;岭兜小区(中区),中共福建光电有限公司支部,福光工业园  闽D0TL89  正北(0)
# 3   福建省厦门市湖里区湖里区无缘水乡;仙岳路;坛烧八味.五常香米饭(弘爱店),厦门颐祥弘爱护理院...  闽D0TL89  正北(0)
# 4   福建省厦门市湖里区湖里区无缘水乡;仙岳路;坛烧八味.五常香米饭(弘爱店),厦门颐祥弘爱护理院...  闽D0TL89  正北(0)
# ..                                                ...      ...    ...
# 85  福建省厦门市思明区梧村街道万寿路103号;万寿路,文屏路-万寿路交叉路口;文园公寓一期,文园...  闽D1YX58  正北(0)
# 86  福建省厦门市思明区开元街道;自强路1号;中国人民解放军第一七四医院,厦门大学附属成功医院,闽...  闽D1YX58  正北(0)
# 87                 福建省厦门市集美区杏林街道;杏滨路2号;华创小区,豪欣公寓,书香公寓  闽D1YX58  正北(0)
# 88  福建省厦门市思明区开元街道;公园东路82号;厦门市第一幼儿园,中山公园-动物园,夏商(新民)...  闽D1YX58  正北(0)
# 89  福建省厦门市集美区侨英街道;印斗北路,印斗北路-信毅路交叉路口;厦门医学院附属第二医院,福建...  闽D1YX58  正北(0)
#
#                 location    TRANSID                           INCEPTADDR  \
# 0    118.155633,24.48001  2243658.0                      厦门市思明区洪莲中路42号店面
# 1   118.166637,24.476225      761.0                             前埔西路295号
# 2    118.174227,24.48246  2229990.0  厦门市思明区前埔路506-508号“国企广场”A栋14层03.05单元
# 3   118.171656,24.506569   876123.0            厦门市湖里区仙岳路3777号 弘爱医院康复楼12楼
# 4   118.171598,24.506673   978080.0                  厦门市湖里区仙岳路3773号B106室
# ..                   ...        ...                                  ...
# 85   118.103568,24.46175    12820.0                         厦门市思明区天虹商场二楼
# 86  118.090147,24.461701     2049.0                         厦门市溪岸路174号\n
# 87  118.056367,24.571737      110.0                           杏林街道苑亭路15号
# 88  118.087385,24.462813     1095.0                             *美仁路242号
# 89   118.099853,24.58699  2244730.0              厦门市集美区侨英街道孙厝乐安东里28-102号
#
#     distance  duration
# 0        0.0       0.0
# 1     2800.0    1019.0
# 2     2970.0    1617.0
# 3     5540.0    1140.0
# 4       10.0      30.0
# ..       ...       ...
# 85   53750.0   63233.0
# 86   54410.0   16648.0
# 87    9230.0   61044.0
# 88     440.0      89.0
# 89   15190.0   10839.0
#
# [90 rows x 14 columns]

# %%
# Shift the columns to pair each row with its next row
filtered_df['destination'] = filtered_df['TRANSID'].shift(-1)
filtered_df['destination_location'] = filtered_df['location'].shift(-1)

# Create the new dataframe df_91
df_91 = filtered_df[['TRANSID', 'location', 'destination', 'destination_location']].copy()
df_91.columns = ['origin', 'origin_location', 'destination', 'destination_location']

# Remove the last row since it doesn't have a destination (because of the shift)
df_91 = df_91[:-1].reset_index(drop=True)
shifted_df = filtered_df.shift(-1)

# Create df_91 using the data from filtered_df and shifted_df
df_91 = pd.DataFrame({
    'origin': filtered_df['TRANSID'],
    'destination': shifted_df['TRANSID'],
    'origin_location': filtered_df['location'],
    'destination_location': shifted_df['location'],
    'distance_r': shifted_df['distance'],
    'duration_r': shifted_df['duration']
})

# Drop the last row since it will have NaN values (because of the shift operation)
df_91 = df_91.dropna().reset_index(drop=True)

df_91
# Out:
#        origin  destination       origin_location  destination_location  \
# 0   2243658.0        761.0   118.155633,24.48001  118.166637,24.476225
# 1       761.0    2229990.0  118.166637,24.476225   118.174227,24.48246
# 2   2229990.0     876123.0   118.174227,24.48246  118.171656,24.506569
# 3    876123.0     978080.0  118.171656,24.506569  118.171598,24.506673
# 4    978080.0    1394159.0  118.171598,24.506673  118.127328,24.495453
# ..        ...          ...                   ...                   ...
# 84     1661.0      12820.0  118.131569,24.491625   118.103568,24.46175
# 85    12820.0       2049.0   118.103568,24.46175  118.090147,24.461701
# 86     2049.0        110.0  118.090147,24.461701  118.056367,24.571737
# 87      110.0       1095.0  118.056367,24.571737  118.087385,24.462813
# 88     1095.0    2244730.0  118.087385,24.462813   118.099853,24.58699
#
#     distance_r  duration_r
# 0       2800.0      1019.0
# 1       2970.0      1617.0
# 2       5540.0      1140.0
# 3         10.0        30.0
# 4     212780.0    340029.0
# ..         ...         ...
# 84     53750.0     63233.0
# 85     54410.0     16648.0
# 86      9230.0     61044.0
# 87       440.0        89.0
# 88     15190.0     10839.0
#
# [89 rows x 6 columns]

# %%
# Save filtered_df to csv file
df_91.to_csv('9.1-停车点100mlocations.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Compare real distance and duration with the api results

# %%
df_cmp = pd.read_csv("9.1-停车点200mlocations_nd.csv")
# Plotting distance vs distance_r
plt.figure(figsize=(14,6))

plt.subplot(1, 2, 1)
plt.plot(df_cmp.index, df_cmp['distance'], label='distance', color='blue')
plt.plot(df_cmp.index, df_cmp['distance_r'], label='distance_r', color='red')
plt.xlabel('Index')
plt.ylabel('Distance Value')
plt.legend()
plt.title('Comparison between distance and distance_r')

# Plotting duration vs duration_r
plt.subplot(1, 2, 2)
plt.plot(df_cmp.index, df_cmp['duration'], label='duration', color='blue')
plt.plot(df_cmp.index, df_cmp['duration_r'], label='duration_r', color='red')
plt.xlabel('Index')
plt.ylabel('Duration Value')
plt.legend()
plt.title('Comparison between duration and duration_r')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Several points shows high difference on distance and duration. This may causes by 两个地点不是前后的送货点，中间有些地点没有被找到；时间差距太大可能司机中途有做别的时间，并不是直接接着送下一个地点的

# %%
df_cmp = df_cmp[(df_cmp['distance_r'] <= 40000) & (df_cmp['duration_r'] <= 10000)]

# Plotting distance vs distance_r
plt.figure(figsize=(14,6))

plt.subplot(1, 2, 1)
plt.plot(df_cmp.index, df_cmp['distance'], label='distance', color='blue')
plt.plot(df_cmp.index, df_cmp['distance_r'], label='distance_r', color='red')
plt.xlabel('Index')
plt.ylabel('Distance Value')
plt.legend()
plt.title('Comparison between distance and distance_r')

# Plotting duration vs duration_r
plt.subplot(1, 2, 2)
plt.plot(df_cmp.index, df_cmp['duration'], label='duration', color='blue')
plt.plot(df_cmp.index, df_cmp['duration_r'], label='duration_r', color='red')
plt.xlabel('Index')
plt.ylabel('Duration Value')
plt.legend()
plt.title('Comparison between duration and duration_r')

plt.tight_layout()
plt.show()

# %%
# Ratio between real distance and gaode_api
df_cmp['distance_ratio'] = df_cmp['distance_r'] / df_cmp['distance']
average_distance_ratio = df_cmp['distance_ratio'].mean()
average_distance_ratio
# Out:
# 1.2781671678372413

# %%
# Ratio between real duration and gaode_api
df_cmp['duration_ratio'] = df_cmp['duration_r'] / df_cmp['duration']
df_cmp['duration_ratio'].mean()
# Out:
# 1.5269653605713114

# %%
# Save filtered_df to csv file
df_cmp.to_csv('9.1-停车点200mlocations_dis4w_dur1w.csv', index=False, encoding='utf-8-sig')
