# %% [markdown]
# # Google OR-Tools 测试

# %% [markdown]
# ## 测试说明
#
# ### 官方页面
#
# https://developers.google.com/optimization/routing/cvrp
#
# ### 算法的输入
#     - 两个地点之间的交通时间
#     - 每个门店的需求量
#     - 每辆货车的最大承载能力
# ### 限制条件
#     - 所有门店的需求量的总和不能大于所有货车的最大承载能力总和
#     - 单家门店的需求量不能大于最大单辆货车承载能力
#     - 时间、需求量、承载能力均为Integer

# %% [markdown]
# ## 运行过程
#
# ### 安装依赖包
#
# 见`requirements.txt`

# %% [markdown]
# ### 运行程序
#     - 数据存储在`./data`文件夹下
#     - 时间矩阵(`distance_matrix`)使用`./gaode/distance_matrix_20221227_1657.csv`
#     - 数据中假设存在1个仓库与111个门店
#     - 门店需求和货车数据为随机生成, 生成代码见`./utils/data_generator.py`
#     - 假设门店需求范围为 [1, 30]
#     - 一共有22辆货车, 每辆车运载能力为 [25, 150]

# %% [markdown]
# # CVRP with simulation data

# %%
import numpy as np
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
import folium
import pandas as pd
from IPython.display import display

def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = np.genfromtxt('./data/distance_matrix.csv', delimiter=',', dtype=int)
    data['demands'] = np.genfromtxt('./data/demands.csv', delimiter=',', dtype=int)[0:112]
    data['vehicle_capacities'] = np.genfromtxt('./data/vehicle_capacities.csv', delimiter=',', dtype=int)
    data['num_vehicles'] = len(data['vehicle_capacities'])
    data['depot'] = 0
    return data


def print_solution(data, manager, routing, solution):
    """Prints solution and plot."""
    locations = pd.read_csv("./gaode/locations.csv")
    print(f'Objective: {solution.ObjectiveValue()}')
    total_distance = 0
    total_load = 0
    trip_df = pd.DataFrame()
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += ' {0} Load({1}) -> '.format(locations['name'][node_index], route_load)
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id)
            trip_df = pd.concat([trip_df, pd.DataFrame({'vehicle_id': [vehicle_id], 'origin': [node_index], 'destination': [manager.IndexToNode(index)]})], ignore_index=True)
        plan_output += ' {0} Load({1})\n'.format(locations['name'][manager.IndexToNode(index)],
                                                 route_load)
        plan_output += 'Distance of the route: {}m\n'.format(route_distance)
        plan_output += 'Load of the route: {}\n'.format(route_load)
        print(plan_output)
        total_distance += route_distance
        total_load += route_load
    print('Total distance of all routes: {}m'.format(total_distance))
    print('Total load of all routes: {}'.format(total_load))
    
    # make folium plot
    category_20 = ('#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c', '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5', 
                   '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f', '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5')
    trip_df = trip_df.query('origin!=0 | destination!=0 ')
    merged_trip_locations = pd.merge(trip_df, locations[['location', 'name']], left_on='origin', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "origin_location", 'name': 'origin_name'}, inplace=True)
    merged_trip_locations = pd.merge(merged_trip_locations, locations[['location', 'name']], left_on='destination', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "destination_location", 'name': 'destination_name'}, inplace=True)
    merged_trip_locations['origin_location'] = merged_trip_locations['origin_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['destination_location'] = merged_trip_locations['destination_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['color'] = merged_trip_locations['vehicle_id'].map(dict(zip(merged_trip_locations['vehicle_id'].unique(), category_20)))

    trip_map = folium.Map([24.48, 118.08], 
                          tiles= 'https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
                          attr='高德-常规图',
                          zoom_start=13,)

    for _, row in merged_trip_locations.iterrows():
        folium.CircleMarker(row['origin_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['origin_name'], 
                           ).add_to(trip_map)
        
        folium.CircleMarker(row['destination_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['destination_name'], 
                           ).add_to(trip_map)
    
        folium.PolyLine([row['origin_location'], row['destination_location']],
                        color=row['color'], 
                       ).add_to(trip_map)
    display(trip_map)

def main():
    """Solve the CVRP problem."""
    # Instantiate the data problem.
    data = create_data_model()

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    # Create and register a transit callback.
    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)


    # Add Capacity constraint.
    def demand_callback(from_index):
        """Returns the demand of the node."""
        # Convert from routing variable Index to demands NodeIndex.
        from_node = manager.IndexToNode(from_index)
        return data['demands'][from_node]

    demand_callback_index = routing.RegisterUnaryTransitCallback(
        demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,  # null capacity slack
        data['vehicle_capacities'],  # vehicle maximum capacities
        True,  # start cumul to zero
        'Capacity')

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH)
    search_parameters.time_limit.FromSeconds(1)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)
   # print(solution)

    # Print solution on console.
    if solution:
        print_solution(data, manager, routing, solution)


if __name__ == '__main__':
    main()
# Out:
# Objective: 1485
# Route for vehicle 0:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(同集北路店) Load(20) ->  鹭燕大药房(银莲路店) Load(24) ->  鹭燕大药房(同安分店) Load(35) ->  鹭燕大药房(大同分店) Load(38) ->  鹭燕大药房(新霞北路店) Load(46) ->  鹭燕大药房(新霞分店) Load(48) ->  鹭燕大药房(巷南分店) Load(52) ->  鹭燕大药房(马巷五星分店) Load(74) ->  燕鹭大药房(巷南路店) Load(83) ->  厦门鹭燕制药有限公司 Load(83)
# Distance of the route: 141m
# Load of the route: 83
#
# Route for vehicle 1:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(马巷分店) Load(21) ->  鹭燕大药房(五权路分店) Load(22) ->  鹭燕大药房(鼓锣东六里店) Load(41) ->  鹭燕大药房(新兴分店) Load(64) ->  鹭燕大药房(新店分店) Load(72) ->  鹭燕大药房(翔安店) Load(101) ->  鹭燕大药房(城场分店) Load(110) ->  鹭燕大药房(浒井分店) Load(124) ->  厦门鹭燕制药有限公司 Load(124)
# Distance of the route: 150m
# Load of the route: 124
#
# Route for vehicle 3:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(SM分店) Load(13) ->  鹭燕大药房(屿后分店) Load(21) ->  鹭燕大药房(后埔分店) Load(26) ->  鹭燕大药房(金民里分店) Load(45) ->  鹭燕大药房(祥店二路分店) Load(46) ->  鹭燕大药房(金尚分店) Load(49) ->  鹭燕大药房(薛岭里店) Load(53) ->  鹭燕大药房(金山分店) Load(67) ->  鹭燕大药房(金湖五里分店) Load(73) ->  鹭燕大药房(金湖路分店) Load(86) ->  鹭燕大药房(吕岭分店) Load(91) ->  鹭燕大药房(七甲路店) Load(113) ->  厦门鹭燕制药有限公司 Load(113)
# Distance of the route: 128m
# Load of the route: 113
#
# Route for vehicle 4:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 5:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 6:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(霞光东里分店) Load(4) ->  鹭燕大药房(霞光东里二分店) Load(8) ->  鹭燕大药房(新阳北路分店) Load(10) ->  鹭燕大药房(松岳分店) Load(24) ->  鹭燕大药房(仙岳路店) Load(46) ->  鹭燕大药房(松柏分店) Load(50) ->  鹭燕大药房(SM二分店) Load(71) ->  鹭燕大药房(兴隆分店) Load(75) ->  厦门鹭燕制药有限公司 Load(75)
# Distance of the route: 93m
# Load of the route: 75
#
# Route for vehicle 7:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(禾祥西分店) Load(29) ->  鹭燕大药房(角滨东路) Load(51) ->  鹭燕大药房(思北大同分店) Load(63) ->  厦门鹭燕制药有限公司 Load(63)
# Distance of the route: 71m
# Load of the route: 63
#
# Route for vehicle 8:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 9:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(镇海分店) Load(4) ->  鹭燕大药房(文园路分店) Load(13) ->  鹭燕大药房(厦大分店) Load(18) ->  鹭燕大药房(和兴分店) Load(26) ->  鹭燕大药房(镇海路分店) Load(47) ->  鹭燕大药房(霞溪路店) Load(59) ->  鹭燕大药房(镇海路新特药店) Load(71) ->  鹭燕大药房(镇海路三分店) Load(87) ->  厦门鹭燕制药有限公司 Load(87)
# Distance of the route: 113m
# Load of the route: 87
#
# Route for vehicle 10:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(枋湖分店) Load(4) ->  鹭燕集团大厦 Load(32) ->  鹭燕大药房(软二分店分店) Load(36) ->  鹭燕大药房(龙虎山路分店) Load(52) ->  鹭燕大药房(东坪山路分店) Load(75) ->  鹭燕大药房(龙景台分店) Load(93) ->  鹭燕大药房(后滨路分店) Load(118) ->  鹭燕大药房(滨南分店) Load(135) ->  厦门鹭燕制药有限公司 Load(135)
# Distance of the route: 131m
# Load of the route: 135
#
# Route for vehicle 11:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 12:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 13:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(官任分店) Load(24) ->  鹭燕大药房(滨北分店) Load(31) ->  鹭燕大药房(后江埭分店) Load(54) ->  鹭燕大药房(岳阳分店) Load(77) ->  厦门鹭燕制药有限公司 Load(77)
# Distance of the route: 78m
# Load of the route: 77
#
# Route for vehicle 14:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 15:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(鱼福三里分店) Load(12) ->  鹭燕大药房(软三分店) Load(33) ->  鹭燕大药房(龙亭三里店) Load(41) ->  鹭燕大药房(集美霞梧分店) Load(47) ->  鹭燕大药房(集美乐海分店) Load(75) ->  鹭燕大药房(塘埔路分店) Load(103) ->  厦门鹭燕制药有限公司 Load(103)
# Distance of the route: 91m
# Load of the route: 103
#
# Route for vehicle 16:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(围里分店) Load(12) ->  鹭燕大药房(五缘尚座分店) Load(21) ->  鹭燕大药房(高林西里店) Load(26) ->  鹭燕大药房(湖边花园分店) Load(39) ->  鹭燕大药房(岭兜一里分店) Load(45) ->  鹭燕大药房(前埔分店) Load(46) ->  鹭燕大药房(瑞景分店) Load(48) ->  鹭燕大药房(洪莲分店) Load(68) ->  鹭燕大药房(洪莲中路店) Load(70) ->  鹭燕大药房(东浦一里分店) Load(74) ->  鹭燕大药房(江头分店) Load(83) ->  厦门鹭燕制药有限公司 Load(83)
# Distance of the route: 135m
# Load of the route: 83
#
# Route for vehicle 17:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(殿前店) Load(7) ->  鹭燕大药房(殿东分店) Load(27) ->  鹭燕大药房(高殿店) Load(56) ->  厦门鹭燕制药有限公司 Load(56)
# Distance of the route: 48m
# Load of the route: 56
#
# Route for vehicle 18:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(孚莲二里店) Load(5) ->  鹭燕大药房(禹州店) Load(27) ->  鹭燕大药房(蓝屿分店) Load(34) ->  鹭燕大药房(沧林东一里分店) Load(51) ->  鹭燕大药房(海沧滨东分店) Load(55) ->  鹭燕大药房(海沧天虹分店) Load(64) ->  鹭燕大药房(沧林路分店) Load(83) ->  鹭燕大药房(海裕路分店) Load(110) ->  鹭燕大药房(海兴分店) Load(139) ->  厦门鹭燕制药有限公司 Load(139)
# Distance of the route: 119m
# Load of the route: 139
#
# Route for vehicle 19:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(寨上分店) Load(13) ->  鹭燕医药 Load(29) ->  鹭燕大药房(宜宾路分店) Load(40) ->  鹭燕大药房(海天路分店) Load(51) ->  鹭燕大药房(旗舰店) Load(65) ->  鹭燕大药房(莲岳分店) Load(83) ->  鹭燕大药房(莲坂新村分店) Load(109) ->  鹭燕医药 Load(117) ->  鹭燕大药房(湖明分店) Load(128) ->  鹭燕大药房(湖东分店) Load(134) ->  鹭燕大药房(和通里分店) Load(135) ->  厦门鹭燕制药有限公司 Load(135)
# Distance of the route: 103m
# Load of the route: 135
#
# Route for vehicle 20:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 21:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房 Load(27) ->  鹭燕大药房(锦英南里分店) Load(39) ->  鹭燕大药房(杏西分店) Load(56) ->  鹭燕大药房(月台分店) Load(58) ->  鹭燕大药房(文屏分店) Load(60) ->  鹭燕大药房(杏东分店) Load(74) ->  鹭燕大药房(宁海五里分店) Load(78) ->  鹭燕大药房(滨水二里店) Load(96) ->  鹭燕大药房(同集南路分店) Load(109) ->  鹭燕大药房(石鼓分店) Load(113) ->  鹭燕大药房(集美岑西分店) Load(115) ->  厦门鹭燕制药有限公司 Load(115)
# Distance of the route: 84m
# Load of the route: 115
#
# Total distance of all routes: 1485m
# Total load of all routes: 1388
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2f2c47e289f444b1fa1e12b782baba7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2f2c47e289f444b1fa1e12b782baba7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2f2c47e289f444b1fa1e12b782baba7 = L.map(
#                 &quot;map_c2f2c47e289f444b1fa1e12b782baba7&quot;,
#                 {
#                     center: [24.48, 118.08],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7f65d80fa9d7f9ce274fc79e028303e = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c2f2c47e289f444b1fa1e12b782baba7);
#
#
#             var circle_marker_d8036ca4477d08e12511da9e7637bc33 = L.circleMarker(
#                 [24.598948, 118.007317],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c2f2c47e289f444b1fa1e12b782baba7);
#
#
#         var popup_be99971064c153f1ae912c30d95d1fa9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c78dbf32040ecea764e6e338f4fa95c = $(`&lt;div id=&quot;html_7c78dbf32040ecea764e6e338f4fa95c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;厦门鹭燕制药有限公司&lt;/div&gt;`)[0];
#                 popup_be99971064c153f1ae912c30d95d1fa9.setContent(html_7c78dbf32040ecea764e6e338f4fa95c);
#
#
#
#         circle_marker_d8036ca4477d08e12511da9e7637bc33.bindPopup(popup_be99971064c153f1ae912c30d95d1fa9)
#         ;
#
#
#
#
#             var circle_marker_468db0e3570acab864593324a3437369 = L.circleMarker(
#                 [24.708456, 118.14467],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c2f2c47e289f444b1fa1e12b782baba7);
#
#
#         var popup_9228c485e52b8e4119b72ea1c29d8d60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d2f8bfb0137533d26fead9c6576a811 = $(`&lt;div id=&quot;html_0d2f8bfb0137533d26fead9c6576a811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;鹭燕大药房(同集北路店)&lt;/div&gt;`)[0];
#                 popup_9228c485e52b8e4119b72ea1c29d8d60.setContent(html_0d2f8bfb0137533d26fead9c6576a811);
#
#
#
#         circle_marker_468db0e3570acab864593324a3437369.bindPopup(popup_9228c485e52b8e4119b72ea1c29d8d60)
#         ;
#
#
#
#
#             var poly_line_90215ed71e6e968500f6074bc6d5e9fe = L.polyline(
#                 [[24.598948, 118.007317], [24.708456, 118.14467]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c2f2c47e289f444b1fa1e12b782baba7);
#
#
#             var circle_marker_8a78ae1605b82181e468943c426f4b04 = L.circleMarker(
#                 [24.708456, 118.14467],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c2f2c47e289f444b1fa1e12b782baba7);
#
#
#         var popup_8c49ba88af6452fced8f929758ffee60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_476478d6650abffd5d08914e0b4fb821 = $(`&lt;div id=&quot;html_476478d6650abffd5d08914e0b4fb821&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;鹭燕大药房(同集北路店)&lt;/d

# %%
locations = pd.read_csv("./gaode/locations.csv")
locations
# Out:
#      Column1      parent            address distance pname importance  \
# 0        111          []  灌口镇灌南工业区安仁大道1599号       []   福建省         []
# 1          0          []         天英二里26、27号       []   福建省         []
# 2          1  B025003MZA      SM城市广场负一层056号       []   福建省         []
# 3          2          []        诚毅北大街61号110       []   福建省         []
# 4          3          []       岑西路125号202店面       []   福建省         []
# ..       ...         ...                ...      ...   ...        ...
# 107      106          []    马巷镇巷南路54号随缘百货对面       []   福建省         []
# 108      107          []          马巷镇民安路60号       []   福建省         []
# 109      108  B02500QFHK        大同路288-290号       []   福建省         []
# 110      109          []   祥平西路223、225、227号       []   福建省         []
# 111      110          []    安岭三路与安岭路交叉口东60米       []   福建省         []
#
#                         biz_ext biz_type cityname               type  ...  \
# 0                            []       []      厦门市       公司企业;公司;医药公司  ...
# 1    {'cost': [], 'rating': []}       []      厦门市  医疗保健服务;医药保健销售店;药房  ...
# 2    {'cost': [], 'rating': []}       []      厦门市  医疗保健服务;医药保健销售店;药房  ...
# 3    {'cost': [], 'rating': []}       []      厦门市  医疗保健服务;医药保健销售店;药房  ...
# 4    {'cost': [], 'rating': []}       []      厦门市  医疗保健服务;医药保健销售店;药房  ...
# ..                          ...      ...      ...                ...  ...
# 107                          []       []      厦门市  医疗保健服务;医药保健销售店;药房  ...
# 108                          []       []      厦门市  医疗保健服务;医药保健销售店;药房  ...
# 109                          []       []      厦门市  医疗保健服务;医药保健销售店;药房  ...
# 110                          []       []      厦门市  医疗保健服务;医药保健销售店;药房  ...
# 111                          []       []      厦门市      商务住宅;楼宇;商务写字楼  ...
#
#     typecode  shopinfo  poiweight childtype adname           name  \
# 0     170203         0         []        []    集美区     厦门鹭燕制药有限公司
# 1      90601         0         []        []    集美区    鹭燕大药房(浒井分店)
# 2      90601         0         []       201    湖里区   鹭燕大药房(SM二分店)
# 3      90601         0         []        []    集美区    鹭燕大药房(软三分店)
# 4      90601         0         []        []    集美区  鹭燕大药房(集美岑西分店)
# ..       ...       ...        ...       ...    ...            ...
# 107    90601         0         []        []    翔安区    燕鹭大药房(巷南路店)
# 108    90601         0         []        []    翔安区    鹭燕大药房(马巷分店)
# 109    90601         0         []       202    思明区  鹭燕大药房(思北大同分店)
# 110    90601         0         []        []    同安区    鹭燕大药房(同安分店)
# 111   120201         0         []        []    湖里区         鹭燕集团大厦
#
#                  location           tel shopid          id
# 0    118.007317,24.598948  0592-8129302     []  B025004PHK
# 1    118.101334,24.604923  0592-6036378     []  B0FFFWA0TG
# 2    118.127344,24.500222  0592-5597622     []  B0FFF3DASO
# 3    118.044874,24.614532  0592-6683686     []  B0FFKPZJLA
# 4    118.095742,24.573115  0592-5731139     []  B0FFFS6BYL
# ..                    ...           ...    ...         ...
# 107  118.253242,24.662151            []     []  B0G0ASU1J6
# 108  118.250164,24.659526  0592-7620280     []  B02500TG8Y
# 109  118.080348,24.456965  0592-2100551     []  B02500S7YU
# 110  118.147349,24.727507  0592-7360028     []  B02500QKZK
# 111  118.162165,24.528856            []     []  B0FFI69UPP
#
# [112 rows x 21 columns]

# %% [markdown]
# # CVRP with 7.21 distance matrix scraped from Gaode

# %%
# Simulated demands and vehicle

def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = np.genfromtxt('./data/dist_mat.csv', delimiter=',', dtype=int)
    data['demands'] = np.genfromtxt('./data/demands.csv', delimiter=',', dtype=int)
    data['vehicle_capacities'] = np.genfromtxt('./data/vehicle_capacities.csv', delimiter=',', dtype=int)
    data['num_vehicles'] = len(data['vehicle_capacities'])
    data['depot'] = 0
    return data


def print_solution(data, manager, routing, solution):
    """Prints solution and plot."""
    locations = pd.read_csv('/Users/wangshuo/Downloads/PyVRP/2023-07-21_Xiamen.csv')
    locations['Indices'] = locations.index
    print(f'Objective: {solution.ObjectiveValue()}')
    total_distance = 0
    total_load = 0
    trip_df = pd.DataFrame()
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += ' {0} Load({1}) -> '.format(locations['Indices'][node_index], route_load)
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id)
            trip_df = pd.concat([trip_df, pd.DataFrame({'vehicle_id': [vehicle_id], 'origin': [node_index], 'destination': [manager.IndexToNode(index)]})], ignore_index=True)
        plan_output += ' {0} Load({1})\n'.format(locations['Indices'][manager.IndexToNode(index)],
                                                 route_load)
        plan_output += 'Distance of the route: {}m\n'.format(route_distance)
        plan_output += 'Load of the route: {}\n'.format(route_load)
        print(plan_output)
        total_distance += route_distance
        total_load += route_load
    print('Total distance of all routes: {}m'.format(total_distance))
    print('Total load of all routes: {}'.format(total_load))
    
    # make folium plot
    category_20 = ('#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c', '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5', 
                   '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f', '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5')
    trip_df = trip_df.query('origin!=0 | destination!=0 ')
    merged_trip_locations = pd.merge(trip_df, locations[['location', 'Indices']], left_on='origin', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "origin_location", 'Indices': 'origin_name'}, inplace=True)
    merged_trip_locations = pd.merge(merged_trip_locations, locations[['location', 'Indices']], left_on='destination', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "destination_location", 'Indices': 'destination_name'}, inplace=True)
    merged_trip_locations['origin_location'] = merged_trip_locations['origin_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['destination_location'] = merged_trip_locations['destination_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['color'] = merged_trip_locations['vehicle_id'].map(dict(zip(merged_trip_locations['vehicle_id'].unique(), category_20)))

    trip_map = folium.Map([24.48, 118.08], 
                          tiles= 'https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
                          attr='高德-常规图',
                          zoom_start=13,)

    for _, row in merged_trip_locations.iterrows():
        folium.CircleMarker(row['origin_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['origin_name'], 
                           ).add_to(trip_map)
        
        folium.CircleMarker(row['destination_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['destination_name'], 
                           ).add_to(trip_map)
    
        folium.PolyLine([row['origin_location'], row['destination_location']],
                        color=row['color'], 
                       ).add_to(trip_map)
    display(trip_map)

def main():
    """Solve the CVRP problem."""
    # Instantiate the data problem.
    data = create_data_model()

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    # Create and register a transit callback.
    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)


    # Add Capacity constraint.
    def demand_callback(from_index):
        """Returns the demand of the node."""
        # Convert from routing variable Index to demands NodeIndex.
        from_node = manager.IndexToNode(from_index)
        return data['demands'][from_node]

    demand_callback_index = routing.RegisterUnaryTransitCallback(
        demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,  # null capacity slack
        data['vehicle_capacities'],  # vehicle maximum capacities
        True,  # start cumul to zero
        'Capacity')

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH)
    search_parameters.time_limit.FromSeconds(1)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)
   # print(solution)

    # Print solution on console.
    if solution:
        print_solution(data, manager, routing, solution)


if __name__ == '__main__':
    main()
# Out:
# Objective: 1317188
# Route for vehicle 0:
#  0 Load(0) ->  210 Load(5) ->  333 Load(29) ->  304 Load(47) ->  163 Load(71) ->  87 Load(86) ->  99 Load(112) ->  43 Load(122) ->  328 Load(134) ->  7 Load(145) ->  161 Load(155) ->  108 Load(184) ->  110 Load(211) ->  218 Load(225) ->  100 Load(242) ->  281 Load(257) ->  284 Load(264) ->  196 Load(268) ->  86 Load(290) ->  68 Load(317) ->  254 Load(342) ->  52 Load(354) ->  50 Load(380) ->  295 Load(400) ->  287 Load(402) ->  314 Load(409) ->  115 Load(431) ->  279 Load(434) ->  97 Load(461) ->  149 Load(484) ->  141 Load(504) ->  56 Load(525) ->  137 Load(546) ->  223 Load(554) ->  24 Load(570) ->  156 Load(575) ->  102 Load(591) ->  159 Load(615) ->  22 Load(630) ->  23 Load(645) ->  177 Load(658) ->  142 Load(675) ->  113 Load(688) ->  341 Load(713) ->  157 Load(721) ->  27 Load(739) ->  33 Load(749) ->  32 Load(758) ->  31 Load(772) ->  30 Load(795) ->  29 Load(823) ->  28 Load(846) ->  92 Load(869) ->  140 Load(897) ->  319 Load(902) ->  318 Load(927) ->  303 Load(933) ->  116 Load(944) ->  95 Load(956) ->  60 Load(961) ->  332 Load(964) ->  278 Load(969) ->  105 Load(995) ->  53 Load(1004) ->  197 Load(1025) ->  65 Load(1032) ->  260 Load(1054) ->  232 Load(1073) ->  214 Load(1090) ->  288 Load(1101) ->  127 Load(1112) ->  37 Load(1118) ->  36 Load(1119) ->  66 Load(1146) ->  107 Load(1161) ->  135 Load(1187) ->  277 Load(1206) ->  219 Load(1
#  0 Load(0) ->  282 Load(6) ->  259 Load(34) ->  283 Load(43) ->  298 Load(66) ->  35 Load(77) ->  74 Load(78) ->  275 Load(88) ->  180 Load(90) ->  55 Load(91) ->  155 Load(105) ->  160 Load(119) ->  0 Load(119)
# Distance of the route: 61017m
# Load of the route: 119
#
# Route for vehicle 2:
#  0 Load(0) ->  138 Load(18) ->  323 Load(35) ->  266 Load(64) ->  4 Load(76) ->  302 Load(97) ->  311 Load(125) ->  294 Load(126) ->  322 Load(128) ->  0 Load(128)
# Distance of the route: 55512m
# Load of the route: 128
#
# Route for vehicle 3:
#  0 Load(0) ->  123 Load(17) ->  117 Load(23) ->  291 Load(35) ->  146 Load(63) ->  78 Load(69) ->  13 Load(70) ->  144 Load(79) ->  0 Load(79)
# Distance of the route: 35018m
# Load of the route: 79
#
# Route for vehicle 4:
#  0 Load(0) ->  209 Load(18) ->  200 Load(42) ->  198 Load(64) ->  181 Load(78) ->  217 Load(79) ->  221 Load(82) ->  0 Load(82)
# Distance of the route: 55624m
# Load of the route: 82
#
# Route for vehicle 5:
#  0 Load(0) ->  286 Load(3) ->  192 Load(10) ->  183 Load(32) ->  229 Load(54) ->  0 Load(54)
# Distance of the route: 32364m
# Load of the route: 54
#
# Route for vehicle 6:
#  0 Load(0) ->  58 Load(29) ->  67 Load(48) ->  148 Load(65) ->  139 Load(84) ->  205 Load(86) ->  71 Load(105) ->  0 Load(105)
# Distance of the route: 47130m
# Load of the route: 105
#
# Route for vehicle 7:
#  0 Load(0) ->  315 Load(23) ->  203 Load(49) ->  193 Load(60) ->  51 Load(62) ->  0 Load(62)
# Distance of the route: 54948m
# Load of the route: 62
#
# Route for vehicle 8:
#  0 Load(0) ->  208 Load(4) ->  331 Load(17) ->  325 Load(44) ->  330 Load(58) ->  0 Load(58)
# Distance of the route: 26883m
# Load of the route: 58
#
# Route for vehicle 9:
#  0 Load(0) ->  251 Load(24) ->  227 Load(52) ->  8 Load(67) ->  46 Load(94) ->  96 Load(114) ->  82 Load(122) ->  133 Load(145) ->  306 Load(149) ->  0 Load(149)
# Distance of the route: 62585m
# Load of the route: 149
#
# Route for vehicle 10:
#  0 Load(0) ->  2 Load(15) ->  307 Load(23) ->  14 Load(33) ->  17 Load(52) ->  297 Load(63) ->  20 Load(64) ->  93 Load(65) ->  0 Load(65)
# Distance of the route: 50734m
# Load of the route: 65
#
# Route for vehicle 11:
#  0 Load(0) ->  234 Load(29) ->  276 Load(49) ->  59 Load(55) ->  178 Load(65) ->  0 Load(65)
# Distance of the route: 37443m
# Load of the route: 65
#
# Route for vehicle 12:
#  0 Load(0) ->  237 Load(25) ->  132 Load(26) ->  128 Load(39) ->  0 Load(39)
# Distance of the route: 46345m
# Load of the route: 39
#
# Route for vehicle 13:
#  0 Load(0) ->  242 Load(25) ->  241 Load(41) ->  239 Load(50) ->  238 Load(55) ->  236 Load(58) ->  235 Load(65) ->  244 Load(67) ->  0 Load(67)
# Distance of the route: 14192m
# Load of the route: 67
#
# Route for vehicle 14:
#  0 Load(0) ->  249 Load(19) ->  248 Load(30) ->  247 Load(35) ->  246 Load(55) ->  245 Load(74) ->  243 Load(100) ->  240 Load(110) ->  272 Load(111) ->  0 Load(111)
# Distance of the route: 30841m
# Load of the route: 111
#
# Route for vehicle 15:
#  0 Load(0) ->  337 Load(4) ->  264 Load(10) ->  262 Load(39) ->  253 Load(55) ->  250 Load(71) ->  103 Load(72) ->  0 Load(72)
# Distance of the route: 58455m
# Load of the route: 72
#
# Route for vehicle 16:
#  0 Load(0) ->  167 Load(7) ->  270 Load(26) ->  47 Load(27) ->  0 Load(27)
# Distance of the route: 51112m
# Load of the route: 27
#
# Route for vehicle 17:
#  0 Load(0) ->  340 Load(6) ->  187 Load(33) ->  64 Load(35) ->  104 Load(36) ->  271 Load(42) ->  77 Load(52) ->  310 Load(64) ->  296 Load(82) ->  15 Load(88) ->  81 Load(96) ->  0 Load(96)
# Distance of the route: 55400m
# Load of the route: 96
#
# Route for vehicle 18:
#  0 Load(0) ->  207 Load(14) ->  327 Load(39) ->  119 Load(67) ->  220 Load(91) ->  230 Load(105) ->  293 Load(123) ->  274 Load(127) ->  1 Load(132) ->  0 Load(132)
# Distance of the route: 39988m
# Load of the route: 132
#
# Route for vehicle 19:
#  0 Load(0) ->  285 Load(23) ->  19 Load(40) ->  317 Load(43) ->  61 Load(44) ->  224 Load(45) ->  143 Load(65) ->  0 Load(65)
# Distance of the route: 55077m
# Load of the route: 65
#
# Route for vehicle 20:
#  0 Load(0) ->  268 Load(22) ->  308 Load(33) ->  44 Load(41) ->  212 Load(49) ->  309 Load(78) ->  265 Load(100) ->  45 Load(115) ->  233 Load(116) ->  199 Load(118) ->  62 Load(119) ->  256 Load(133) ->  0 Load(133)
# Distance of the route: 59273m
# Load of the route: 133
#
# Route for vehicle 21:
#  0 Load(0) ->  313 Load(12) ->  273 Load(35) ->  326 Load(42) ->  0 Load(42)
# Distance of the route: 9950m
# Load of the route: 42
#
# Total distance of all routes: 1317188m
# Total load of all routes: 5053
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5344a0c217b93dc34b1af9e58d105dbe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5344a0c217b93dc34b1af9e58d105dbe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5344a0c217b93dc34b1af9e58d105dbe = L.map(
#                 &quot;map_5344a0c217b93dc34b1af9e58d105dbe&quot;,
#                 {
#                     center: [24.48, 118.08],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_111901e8db1df48b96facad3ec863765 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5344a0c217b93dc34b1af9e58d105dbe);
#
#
#             var circle_marker_545fdc76b4868a03c89bde2857a9f52d = L.circleMarker(
#                 [24.598948, 118.007317],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5344a0c217b93dc34b1af9e58d105dbe);
#
#
#         var popup_451dd8cd76af8313e9f58e511f92f66c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e83f9388b0be33e8959169e5e2031f44 = $(`&lt;div id=&quot;html_e83f9388b0be33e8959169e5e2031f44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_451dd8cd76af8313e9f58e511f92f66c.setContent(html_e83f9388b0be33e8959169e5e2031f44);
#
#
#
#         circle_marker_545fdc76b4868a03c89bde2857a9f52d.bindPopup(popup_451dd8cd76af8313e9f58e511f92f66c)
#         ;
#
#
#
#
#             var circle_marker_3ae2fd9800523e53757cb5f353502441 = L.circleMarker(
#                 [24.532742, 118.110804],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5344a0c217b93dc34b1af9e58d105dbe);
#
#
#         var popup_65731abfe994e6171b58a18b9e8bda46 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1894ca06cf6da30f6b315c668e2d3e1e = $(`&lt;div id=&quot;html_1894ca06cf6da30f6b315c668e2d3e1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;210&lt;/div&gt;`)[0];
#                 popup_65731abfe994e6171b58a18b9e8bda46.setContent(html_1894ca06cf6da30f6b315c668e2d3e1e);
#
#
#
#         circle_marker_3ae2fd9800523e53757cb5f353502441.bindPopup(popup_65731abfe994e6171b58a18b9e8bda46)
#         ;
#
#
#
#
#             var poly_line_5d0724494e10876088e1b9f49e072278 = L.polyline(
#                 [[24.598948, 118.007317], [24.532742, 118.110804]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5344a0c217b93dc34b1af9e58d105dbe);
#
#
#             var circle_marker_7b6f9416a609863ed650e4106c9fb0b0 = L.circleMarker(
#                 [24.532742, 118.110804],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5344a0c217b93dc34b1af9e58d105dbe);
#
#
#         var popup_b7719769237d3b1377ed662c2ef5c4bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a89c7bc0744820b01fa9eb71968faba = $(`&lt;div id=&quot;html_0a89c7bc0744820b01fa9eb71968faba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;210&lt;/div&gt;`)[0];

# %%
# Simulated demands
def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = np.genfromtxt('./data/dist_mat.csv', delimiter=',', dtype=int)
    data['demands'] = np.genfromtxt('./data/demands.csv', delimiter=',', dtype=int)
    data['vehicle_capacities'] = np.genfromtxt('./data/vehicle.csv', delimiter=',', dtype=int)
    data['num_vehicles'] = len(data['vehicle_capacities'])
    data['depot'] = 0
    return data


def print_solution(data, manager, routing, solution):
    """Prints solution and plot."""
    locations = pd.read_csv('/Users/wangshuo/Downloads/PyVRP/2023-07-21_Xiamen.csv')
    locations['Indices'] = locations.index
    print(f'Objective: {solution.ObjectiveValue()}')
    total_distance = 0
    total_load = 0
    trip_df = pd.DataFrame()
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += ' {0} Load({1}) -> '.format(locations['Indices'][node_index], route_load)
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id)
            trip_df = pd.concat([trip_df, pd.DataFrame({'vehicle_id': [vehicle_id], 'origin': [node_index], 'destination': [manager.IndexToNode(index)]})], ignore_index=True)
        plan_output += ' {0} Load({1})\n'.format(locations['Indices'][manager.IndexToNode(index)],
                                                 route_load)
        plan_output += 'Distance of the route: {}m\n'.format(route_distance)
        plan_output += 'Load of the route: {}\n'.format(route_load)
        print(plan_output)
        total_distance += route_distance
        total_load += route_load
    print('Total distance of all routes: {}m'.format(total_distance))
    print('Total load of all routes: {}'.format(total_load))
    
    # make folium plot
    category_20 = ('#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c', '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5', 
                   '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f', '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5')
    trip_df = trip_df.query('origin!=0 | destination!=0 ')
    merged_trip_locations = pd.merge(trip_df, locations[['location', 'Indices']], left_on='origin', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "origin_location", 'Indices': 'origin_name'}, inplace=True)
    merged_trip_locations = pd.merge(merged_trip_locations, locations[['location', 'Indices']], left_on='destination', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "destination_location", 'Indices': 'destination_name'}, inplace=True)
    merged_trip_locations['origin_location'] = merged_trip_locations['origin_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['destination_location'] = merged_trip_locations['destination_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['color'] = merged_trip_locations['vehicle_id'].map(dict(zip(merged_trip_locations['vehicle_id'].unique(), category_20)))

    trip_map = folium.Map([24.48, 118.08], 
                          tiles= 'https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
                          attr='高德-常规图',
                          zoom_start=13,)

    for _, row in merged_trip_locations.iterrows():
        folium.CircleMarker(row['origin_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['origin_name'], 
                           ).add_to(trip_map)
        
        folium.CircleMarker(row['destination_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['destination_name'], 
                           ).add_to(trip_map)
    
        folium.PolyLine([row['origin_location'], row['destination_location']],
                        color=row['color'], 
                       ).add_to(trip_map)
    display(trip_map)

def main():
    """Solve the CVRP problem."""
    # Instantiate the data problem.
    data = create_data_model()

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    # Create and register a transit callback.
    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)


    # Add Capacity constraint.
    def demand_callback(from_index):
        """Returns the demand of the node."""
        # Convert from routing variable Index to demands NodeIndex.
        from_node = manager.IndexToNode(from_index)
        return data['demands'][from_node]

    demand_callback_index = routing.RegisterUnaryTransitCallback(
        demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,  # null capacity slack
        data['vehicle_capacities'],  # vehicle maximum capacities
        True,  # start cumul to zero
        'Capacity')

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH)
    search_parameters.time_limit.FromSeconds(1)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)
#  0 Load(0) ->  289 Load(13) ->  18 Load(22) ->  335 Load(42) ->  216 Load(65) ->  118 Load(92) ->  215 Load(96) ->  174 Load(110) ->  170 Load(137) ->  168 Load(145) ->  188 Load(164) ->  145 Load(168) ->  305 Load(174) ->  255 Load(196) ->  165 Load(199) ->  164 Load(225) ->  69 Load(250) ->  70 Load(264) ->  190 Load(290) ->  292 Load(304) ->  225 Load(322) ->  201 Load(333) ->  130 Load(357) ->  158 Load(360) ->  267 Load(379) ->  217 Load(380) ->  189 Load(386) ->  172 Load(414) ->  76 Load(443) ->  10 Load(446) ->  85 Load(473) ->  166 Load(488) ->  150 Load(516) ->  147 Load(525) ->  126 Load(527) ->  109 Load(536) ->  151 Load(557) ->  204 Load(583) ->  98 Load(603) ->  258 Load(618) ->  261 Load(631) ->  202 Load(646) ->  320 Load(660) ->  191 Load(681) ->  124 Load(684) ->  62 Load(685) ->  199 Load(687) ->  72 Load(700) ->  121 Load(704) ->  6 Load(729) ->  23 Load(744) ->  137 Load(765) ->  287 Load(767) ->  136 Load(782) ->  295 Load(802) ->  169 Load(828) ->  339 Load(854) ->  328 Load(866) ->  43 Load(876) ->  104 Load(877) ->  7 Load(888) ->  317 Load(891) ->  161 Load(901) ->  12 Load(915) ->  11 Load(943) ->  84 Load(962) ->  108 Load(991) ->  110 Load(1018) ->  218 Load(1032) ->  100 Load(1049) ->  233 Load(1050) ->  284 Load(1057) ->  196 Load(1061) ->  86 Load(1083) ->  79 Load(1107) ->  254 Load(1132) ->  52 Load(1144) ->  20 Load(1145) ->  93 Load(1146) ->  26 Load(1165) ->  3 Load(1186) ->  176 Load(1206) ->  50 Load(1232) ->  314 Load(1239) ->  281 Load(1254) ->  99 Load(1280) ->  163 Load(1304) ->  304 Load(1322) ->  0 Load(1322)
# Distance of the route: 140497m
# Load of the route: 1322
#
# Total distance of all routes: 675393m
# Total load of all routes: 5053
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52b6c6b85a1a9dbe61fbcb0ff9245bf9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52b6c6b85a1a9dbe61fbcb0ff9245bf9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52b6c6b85a1a9dbe61fbcb0ff9245bf9 = L.map(
#                 &quot;map_52b6c6b85a1a9dbe61fbcb0ff9245bf9&quot;,
#                 {
#                     center: [24.48, 118.08],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_766f21545623e845101066a9af70c4c2 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_52b6c6b85a1a9dbe61fbcb0ff9245bf9);
#
#
#             var circle_marker_38505c446d5a545f7054b6aa34e758c5 = L.circleMarker(
#                 [24.598948, 118.007317],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_52b6c6b85a1a9dbe61fbcb0ff9245bf9);
#
#
#         var popup_e34078ff60580fafaa64e4a712fb5653 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f63891fc579eaa0e9ec75fcab44ff946 = $(`&lt;div id=&quot;html_f63891fc579eaa0e9ec75fcab44ff946&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_e34078ff60580fafaa64e4a712fb5653.setContent(html_f63891fc579eaa0e9ec75fcab44ff946);
#
#
#
#         circle_marker_38505c446d5a545f7054b6aa34e758c5.bindPopup(popup_e34078ff60580fafaa64e4a712fb5653)
#         ;
#
#
#
#
#             var circle_marker_12556fe877ad73e145c969aaa92f7e5b = L.circleMarker(
#                 [24.532742, 118.110804],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_52b6c6b85a1a9dbe61fbcb0ff9245bf9);
#
#
#         var popup_022f2ce798f145117596a6e968d67aff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9fb01e8cd2538bf016295ffa013445ea = $(`&lt;div id=&quot;html_9fb01e8cd2538bf016295ffa013445ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;210&lt;/div&gt;`)[0];
#                 popup_022f2ce798f145117596a6e968d67aff.setContent(html_9fb01e8cd2538bf016295ffa013445ea);
#
#
#
#         circle_marker_12556fe877ad73e145c969aaa92f7e5b.bindPopup(popup_022f2ce798f145117596a6e968d67aff)
#         ;
#
#
#
#
#             var poly_line_c9dc2a265b400d8843f94c126c023860 = L.polyline(
#                 [[24.598948, 118.007317], [24.532742, 118.110804]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_52b6c6b85a1a9dbe61fbcb0ff9245bf9);
#
#
#             var circle_marker_32de671a5f6621572a157648271c912a = L.circleMarker(
#                 [24.532742, 118.110804],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_52b6c6b85a1a9dbe61fbcb0ff9245bf9);
#
#
#         var popup_19c858361a4adf197306eab1de6ee3fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56a77d918670ce4089a0357185178721 = $(`&lt;div id=&quot;html_56a77d918670ce4089a0357185178721&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;210&lt;/div&gt;`)[0];

# %%
#All real data
def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = np.genfromtxt('./data/dist_mat.csv', delimiter=',', dtype=int)
    data['demands'] = np.genfromtxt('./data/demand.csv', delimiter=',', dtype=int)
    data['vehicle_capacities'] = np.genfromtxt('./data/vehicle.csv', delimiter=',', dtype=int)
    data['num_vehicles'] = len(data['vehicle_capacities'])
    data['depot'] = 0
    return data


def print_solution(data, manager, routing, solution):
    """Prints solution and plot."""
    locations = pd.read_csv('/Users/wangshuo/Downloads/PyVRP/2023-07-21_Xiamen.csv')
    locations['Indices'] = locations.index
    print(f'Objective: {solution.ObjectiveValue()}')
    total_distance = 0
    total_load = 0
    trip_df = pd.DataFrame()
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += ' {0} Load({1}) -> '.format(locations['Indices'][node_index], route_load)
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id)
            trip_df = pd.concat([trip_df, pd.DataFrame({'vehicle_id': [vehicle_id], 'origin': [node_index], 'destination': [manager.IndexToNode(index)]})], ignore_index=True)
        plan_output += ' {0} Load({1})\n'.format(locations['Indices'][manager.IndexToNode(index)],
                                                 route_load)
        plan_output += 'Distance of the route: {}m\n'.format(route_distance)
        plan_output += 'Load of the route: {}\n'.format(route_load)
        print(plan_output)
        total_distance += route_distance
        total_load += route_load
    print('Total distance of all routes: {}m'.format(total_distance))
    print('Total load of all routes: {}'.format(total_load))
    
    # make folium plot
    category_20 = ('#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c', '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5', 
                   '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f', '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5')
    trip_df = trip_df.query('origin!=0 | destination!=0 ')
    merged_trip_locations = pd.merge(trip_df, locations[['location', 'Indices']], left_on='origin', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "origin_location", 'Indices': 'origin_name'}, inplace=True)
    merged_trip_locations = pd.merge(merged_trip_locations, locations[['location', 'Indices']], left_on='destination', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "destination_location", 'Indices': 'destination_name'}, inplace=True)
    merged_trip_locations['origin_location'] = merged_trip_locations['origin_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['destination_location'] = merged_trip_locations['destination_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['color'] = merged_trip_locations['vehicle_id'].map(dict(zip(merged_trip_locations['vehicle_id'].unique(), category_20)))

    trip_map = folium.Map([24.48, 118.08], 
                          tiles= 'https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
                          attr='高德-常规图',
                          zoom_start=13,)

    for _, row in merged_trip_locations.iterrows():
        folium.CircleMarker(row['origin_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['origin_name'], 
                           ).add_to(trip_map)
        
        folium.CircleMarker(row['destination_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['destination_name'], 
                           ).add_to(trip_map)
    
        folium.PolyLine([row['origin_location'], row['destination_location']],
                        color=row['color'], 
                       ).add_to(trip_map)
    display(trip_map)

def main():
    """Solve the CVRP problem."""
    # Instantiate the data problem.
    data = create_data_model()

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    # Create and register a transit callback.
    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)


    # Add Capacity constraint.
    def demand_callback(from_index):
        """Returns the demand of the node."""
        # Convert from routing variable Index to demands NodeIndex.
        from_node = manager.IndexToNode(from_index)
        return data['demands'][from_node]

    demand_callback_index = routing.RegisterUnaryTransitCallback(
        demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,  # null capacity slack
        data['vehicle_capacities'],  # vehicle maximum capacities
        True,  # start cumul to zero
        'Capacity')

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH)
    search_parameters.time_limit.FromSeconds(1)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)
   # print(solution)

    # Print solution on console.
    if solution:
        print_solution(data, manager, routing, solution)


if __name__ == '__main__':
    main()
