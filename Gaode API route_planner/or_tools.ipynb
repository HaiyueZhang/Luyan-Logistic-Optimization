# %% [markdown]
# # Google OR-Tools 测试

# %% [markdown]
# ## 测试说明
#
# ### 官方页面
#
# https://developers.google.com/optimization/routing/cvrp
#
# ### 算法的输入
#     - 两个地点之间的交通时间
#     - 每个门店的需求量
#     - 每辆货车的最大承载能力
# ### 限制条件
#     - 所有门店的需求量的总和不能大于所有货车的最大承载能力总和
#     - 单家门店的需求量不能大于最大单辆货车承载能力
#     - 时间、需求量、承载能力均为Integer

# %% [markdown]
# ## 运行过程
#
# ### 安装依赖包
#
# 见`requirements.txt`

# %% [markdown]
# ### 运行程序
#     - 数据存储在`./data`文件夹下
#     - 时间矩阵(`distance_matrix`)使用`./gaode/distance_matrix_20221227_1657.csv`
#     - 数据中假设存在1个仓库与111个门店
#     - 门店需求和货车数据为随机生成, 生成代码见`./utils/data_generator.py`
#     - 假设门店需求范围为 [1, 30]
#     - 一共有22辆货车, 每辆车运载能力为 [25, 150]

# %%
import numpy as np
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
import folium
import pandas as pd
from IPython.display import display

def create_data_model():
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = np.genfromtxt('./data/distance_matrix.csv', delimiter=',', dtype=int)
    data['demands'] = np.genfromtxt('./data/demands.csv', delimiter=',', dtype=int)
    data['vehicle_capacities'] = np.genfromtxt('./data/vehicle_capacities.csv', delimiter=',', dtype=int)
    data['num_vehicles'] = len(data['vehicle_capacities'])
    data['depot'] = 0
    return data


def print_solution(data, manager, routing, solution):
    """Prints solution and plot."""
    locations = pd.read_csv("./gaode/locations.csv")
    print(f'Objective: {solution.ObjectiveValue()}')
    total_distance = 0
    total_load = 0
    trip_df = pd.DataFrame()
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        plan_output = 'Route for vehicle {}:\n'.format(vehicle_id)
        route_distance = 0
        route_load = 0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data['demands'][node_index]
            plan_output += ' {0} Load({1}) -> '.format(locations['name'][node_index], route_load)
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id)
            trip_df = pd.concat([trip_df, pd.DataFrame({'vehicle_id': [vehicle_id], 'origin': [node_index], 'destination': [manager.IndexToNode(index)]})], ignore_index=True)
        plan_output += ' {0} Load({1})\n'.format(locations['name'][manager.IndexToNode(index)],
                                                 route_load)
        plan_output += 'Distance of the route: {}m\n'.format(route_distance)
        plan_output += 'Load of the route: {}\n'.format(route_load)
        print(plan_output)
        total_distance += route_distance
        total_load += route_load
    print('Total distance of all routes: {}m'.format(total_distance))
    print('Total load of all routes: {}'.format(total_load))
    
    # make folium plot
    category_20 = ('#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c', '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5', 
                   '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f', '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5')
    trip_df = trip_df.query('origin!=0 | destination!=0 ')
    merged_trip_locations = pd.merge(trip_df, locations[['location', 'name']], left_on='origin', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "origin_location", 'name': 'origin_name'}, inplace=True)
    merged_trip_locations = pd.merge(merged_trip_locations, locations[['location', 'name']], left_on='destination', right_index=True, how='left')
    merged_trip_locations.rename(columns={'location': "destination_location", 'name': 'destination_name'}, inplace=True)
    merged_trip_locations['origin_location'] = merged_trip_locations['origin_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['destination_location'] = merged_trip_locations['destination_location'].apply(lambda x: [float(i) for i in x.split(",")][::-1])
    merged_trip_locations['color'] = merged_trip_locations['vehicle_id'].map(dict(zip(merged_trip_locations['vehicle_id'].unique(), category_20)))

    trip_map = folium.Map([24.48, 118.08], 
                          tiles= 'https://wprd01.is.autonavi.com/appmaptile?x={x}&y={y}&z={z}&lang=zh_cn&size=1&scl=1&style=7',
                          attr='高德-常规图',
                          zoom_start=13,)

    for _, row in merged_trip_locations.iterrows():
        folium.CircleMarker(row['origin_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['origin_name'], 
                           ).add_to(trip_map)
        
        folium.CircleMarker(row['destination_location'],
                            radius=3,
                            fill_color=row['color'], 
                            color=row['color'], 
                            popup=row['destination_name'], 
                           ).add_to(trip_map)
    
        folium.PolyLine([row['origin_location'], row['destination_location']],
                        color=row['color'], 
                       ).add_to(trip_map)
    display(trip_map)

def main():
    """Solve the CVRP problem."""
    # Instantiate the data problem.
    data = create_data_model()

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    # Create and register a transit callback.
    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)


    # Add Capacity constraint.
    def demand_callback(from_index):
        """Returns the demand of the node."""
        # Convert from routing variable Index to demands NodeIndex.
        from_node = manager.IndexToNode(from_index)
        return data['demands'][from_node]

    demand_callback_index = routing.RegisterUnaryTransitCallback(
        demand_callback)
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,  # null capacity slack
        data['vehicle_capacities'],  # vehicle maximum capacities
        True,  # start cumul to zero
        'Capacity')

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH)
    search_parameters.time_limit.FromSeconds(1)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        print_solution(data, manager, routing, solution)


if __name__ == '__main__':
    main()
# Out:
# Objective: 1736
# Route for vehicle 0:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 1:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 2:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Route for vehicle 3:
#  厦门鹭燕制药有限公司 Load(0) ->  燕鹭大药房(巷南路店) Load(18) ->  鹭燕大药房(马巷五星分店) Load(44) ->  鹭燕大药房(巷南分店) Load(59) ->  鹭燕大药房(马巷分店) Load(79) ->  鹭燕大药房(鼓锣东六里店) Load(92) ->  鹭燕大药房(新兴分店) Load(111) ->  鹭燕大药房(新店分店) Load(113) ->  鹭燕大药房(翔安店) Load(123) ->  鹭燕大药房(城场分店) Load(141) ->  厦门鹭燕制药有限公司 Load(141)
# Distance of the route: 142m
# Load of the route: 141
#
# Route for vehicle 4:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(屿后分店) Load(6) ->  鹭燕大药房(东坪山路分店) Load(17) ->  鹭燕大药房(文园路分店) Load(27) ->  鹭燕大药房(镇海分店) Load(43) ->  鹭燕大药房(镇海路分店) Load(63) ->  鹭燕大药房(霞溪路店) Load(71) ->  鹭燕大药房(镇海路新特药店) Load(74) ->  鹭燕大药房(镇海路三分店) Load(100) ->  厦门鹭燕制药有限公司 Load(100)
# Distance of the route: 109m
# Load of the route: 100
#
# Route for vehicle 5:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(七甲路店) Load(29) ->  鹭燕大药房(鱼福三里分店) Load(52) ->  厦门鹭燕制药有限公司 Load(52)
# Distance of the route: 21m
# Load of the route: 52
#
# Route for vehicle 6:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(官任分店) Load(5) ->  鹭燕大药房(滨北分店) Load(27) ->  鹭燕大药房(后江埭分店) Load(56) ->  鹭燕大药房(后滨路分店) Load(74) ->  鹭燕大药房(滨南分店) Load(94) ->  鹭燕大药房(海天路分店) Load(117) ->  厦门鹭燕制药有限公司 Load(117)
# Distance of the route: 90m
# Load of the route: 117
#
# Route for vehicle 7:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(银莲路店) Load(22) ->  鹭燕大药房(大同分店) Load(40) ->  鹭燕大药房(同安分店) Load(42) ->  鹭燕大药房(同集北路店) Load(59) ->  厦门鹭燕制药有限公司 Load(59)
# Distance of the route: 83m
# Load of the route: 59
#
# Route for vehicle 8:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(禾祥西分店) Load(16) ->  鹭燕大药房(角滨东路) Load(32) ->  鹭燕大药房(思北大同分店) Load(61) ->  厦门鹭燕制药有限公司 Load(61)
# Distance of the route: 71m
# Load of the route: 61
#
# Route for vehicle 9:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(围里分店) Load(15) ->  鹭燕集团大厦 Load(22) ->  鹭燕大药房(软二分店分店) Load(41) ->  鹭燕大药房(前埔分店) Load(61) ->  鹭燕大药房(洪莲分店) Load(66) ->  鹭燕医药 Load(68) ->  鹭燕大药房(湖明分店) Load(78) ->  厦门鹭燕制药有限公司 Load(78)
# Distance of the route: 122m
# Load of the route: 78
#
# Route for vehicle 10:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(霞光东里分店) Load(14) ->  鹭燕大药房(霞光东里二分店) Load(28) ->  鹭燕大药房(新阳北路分店) Load(36) ->  鹭燕大药房(海兴分店) Load(63) ->  鹭燕大药房(海裕路分店) Load(73) ->  鹭燕大药房(沧林路分店) Load(75) ->  鹭燕大药房(海沧滨东分店) Load(80) ->  鹭燕大药房(沧林东一里分店) Load(87) ->  厦门鹭燕制药有限公司 Load(87)
# Distance of the route: 89m
# Load of the route: 87
#
# Route for vehicle 11:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(金湖五里分店) Load(22) ->  鹭燕大药房(金湖路分店) Load(50) ->  鹭燕大药房(吕岭分店) Load(65) ->  鹭燕大药房(仙岳路店) Load(85) ->  鹭燕大药房(宜宾路分店) Load(103) ->  鹭燕医药 Load(122) ->  厦门鹭燕制药有限公司 Load(122)
# Distance of the route: 100m
# Load of the route: 122
#
# Route for vehicle 12:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(兴隆分店) Load(26) ->  鹭燕大药房(SM二分店) Load(48) ->  鹭燕大药房(SM分店) Load(65) ->  鹭燕大药房(祥店二路分店) Load(80) ->  厦门鹭燕制药有限公司 Load(80)
# Distance of the route: 74m
# Load of the route: 80
#
# Route for vehicle 13:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(瑞景分店) Load(25) ->  鹭燕大药房(东浦一里分店) Load(49) ->  鹭燕大药房(厦大分店) Load(70) ->  鹭燕大药房(和兴分店) Load(77) ->  厦门鹭燕制药有限公司 Load(77)
# Distance of the route: 109m
# Load of the route: 77
#
# Route for vehicle 14:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(杏西分店) Load(22) ->  鹭燕大药房(月台分店) Load(23) ->  鹭燕大药房(文屏分店) Load(34) ->  鹭燕大药房(杏东分店) Load(60) ->  鹭燕大药房(宁海五里分店) Load(66) ->  厦门鹭燕制药有限公司 Load(66)
# Distance of the route: 56m
# Load of the route: 66
#
# Route for vehicle 15:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(五权路分店) Load(27) ->  鹭燕大药房(高林西里店) Load(44) ->  鹭燕大药房(湖边花园分店) Load(48) ->  鹭燕大药房(岭兜一里分店) Load(59) ->  鹭燕大药房(洪莲中路店) Load(63) ->  鹭燕大药房(五缘尚座分店) Load(69) ->  鹭燕大药房(枋湖分店) Load(75) ->  鹭燕大药房(金山分店) Load(81) ->  鹭燕大药房(金尚分店) Load(83) ->  鹭燕大药房(薛岭里店) Load(85) ->  鹭燕大药房(松柏分店) Load(91) ->  鹭燕大药房(滨水二里店) Load(92) ->  鹭燕大药房(浒井分店) Load(113) ->  厦门鹭燕制药有限公司 Load(113)
# Distance of the route: 185m
# Load of the route: 113
#
# Route for vehicle 16:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(孚莲二里店) Load(22) ->  鹭燕大药房(禹州店) Load(28) ->  鹭燕大药房(蓝屿分店) Load(50) ->  鹭燕大药房(海沧天虹分店) Load(68) ->  鹭燕大药房(旗舰店) Load(81) ->  鹭燕大药房(松岳分店) Load(82) ->  鹭燕大药房(岳阳分店) Load(110) ->  鹭燕大药房(和通里分店) Load(115) ->  厦门鹭燕制药有限公司 Load(115)
# Distance of the route: 129m
# Load of the route: 115
#
# Route for vehicle 17:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(集美岑西分店) Load(24) ->  鹭燕大药房(石鼓分店) Load(28) ->  鹭燕大药房(寨上分店) Load(42) ->  鹭燕大药房(高殿店) Load(47) ->  鹭燕大药房(殿东分店) Load(67) ->  鹭燕大药房(殿前店) Load(78) ->  厦门鹭燕制药有限公司 Load(78)
# Distance of the route: 71m
# Load of the route: 78
#
# Route for vehicle 18:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(锦英南里分店) Load(28) ->  鹭燕大药房(龙亭三里店) Load(41) ->  鹭燕大药房(软三分店) Load(69) ->  鹭燕大药房 Load(85) ->  厦门鹭燕制药有限公司 Load(85)
# Distance of the route: 49m
# Load of the route: 85
#
# Route for vehicle 19:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(新霞北路店) Load(27) ->  鹭燕大药房(新霞分店) Load(47) ->  鹭燕大药房(集美霞梧分店) Load(69) ->  鹭燕大药房(集美乐海分店) Load(92) ->  鹭燕大药房(同集南路分店) Load(95) ->  鹭燕大药房(塘埔路分店) Load(104) ->  厦门鹭燕制药有限公司 Load(104)
# Distance of the route: 124m
# Load of the route: 104
#
# Route for vehicle 20:
#  厦门鹭燕制药有限公司 Load(0) ->  鹭燕大药房(莲岳分店) Load(11) ->  鹭燕大药房(莲坂新村分店) Load(30) ->  鹭燕大药房(湖东分店) Load(43) ->  鹭燕大药房(龙景台分店) Load(52) ->  鹭燕大药房(龙虎山路分店) Load(57) ->  鹭燕大药房(金民里分店) Load(81) ->  鹭燕大药房(后埔分店) Load(106) ->  鹭燕大药房(江头分店) Load(122) ->  厦门鹭燕制药有限公司 Load(122)
# Distance of the route: 112m
# Load of the route: 122
#
# Route for vehicle 21:
#  厦门鹭燕制药有限公司 Load(0) ->  厦门鹭燕制药有限公司 Load(0)
# Distance of the route: 0m
# Load of the route: 0
#
# Total distance of all routes: 1736m
# Total load of all routes: 1657
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c86542116cace0b16800cca1c256a0e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c86542116cace0b16800cca1c256a0e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c86542116cace0b16800cca1c256a0e8 = L.map(
#                 &quot;map_c86542116cace0b16800cca1c256a0e8&quot;,
#                 {
#                     center: [24.48, 118.08],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f5c7916ed466ae7fe51eb97ab1ef4f1 = L.tileLayer(
#                 &quot;https://wprd01.is.autonavi.com/appmaptile?x={x}\u0026y={y}\u0026z={z}\u0026lang=zh_cn\u0026size=1\u0026scl=1\u0026style=7&quot;,
#                 {&quot;attribution&quot;: &quot;\u9ad8\u5fb7-\u5e38\u89c4\u56fe&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c86542116cace0b16800cca1c256a0e8);
#
#
#             var circle_marker_e1ed2f7919c701aafe86b6cae3f03591 = L.circleMarker(
#                 [24.598948, 118.007317],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c86542116cace0b16800cca1c256a0e8);
#
#
#         var popup_6c9d453a5e6ab6927188496ebe237b4a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea5302fe2341da7df7d4c4f2afd3dd03 = $(`&lt;div id=&quot;html_ea5302fe2341da7df7d4c4f2afd3dd03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;厦门鹭燕制药有限公司&lt;/div&gt;`)[0];
#                 popup_6c9d453a5e6ab6927188496ebe237b4a.setContent(html_ea5302fe2341da7df7d4c4f2afd3dd03);
#
#
#
#         circle_marker_e1ed2f7919c701aafe86b6cae3f03591.bindPopup(popup_6c9d453a5e6ab6927188496ebe237b4a)
#         ;
#
#
#
#
#             var circle_marker_5a767373e68d641d309917907b15b999 = L.circleMarker(
#                 [24.662151, 118.253242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c86542116cace0b16800cca1c256a0e8);
#
#
#         var popup_dbbcee44d95d8fdd6d095a778ccef782 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3379f1232bb0c96d44684ebb2bd0292f = $(`&lt;div id=&quot;html_3379f1232bb0c96d44684ebb2bd0292f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;燕鹭大药房(巷南路店)&lt;/div&gt;`)[0];
#                 popup_dbbcee44d95d8fdd6d095a778ccef782.setContent(html_3379f1232bb0c96d44684ebb2bd0292f);
#
#
#
#         circle_marker_5a767373e68d641d309917907b15b999.bindPopup(popup_dbbcee44d95d8fdd6d095a778ccef782)
#         ;
#
#
#
#
#             var poly_line_49ec9121389c07642bd715025872f2d7 = L.polyline(
#                 [[24.598948, 118.007317], [24.662151, 118.253242]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c86542116cace0b16800cca1c256a0e8);
#
#
#             var circle_marker_8548a63b6471f42b133b9793281aa237 = L.circleMarker(
#                 [24.662151, 118.253242],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c86542116cace0b16800cca1c256a0e8);
#
#
#         var popup_eee0a05118340c8a0cbd0d9b1bbb9aae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e52523fe040cf138cd5325c93f850405 = $(`&lt;div id=&quot;html_e52523fe040cf138cd5325c93f850405&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;燕鹭大药房(巷南路店)&lt;/

# %% [markdown]
# ### 结果评估
#
#     - 与现有运输方案比较
#         - 总运输时间
#         - 运载率: 派出车辆的总运输量/总可承载量
#     - 应用细节问题
#         - 在门店的装卸货时间是否应该加入运输时间(按装载量估算, 或者如果门店处有记载也可以按门店计算时间与需求关系)
#         - 门店需求对应的装箱体积是否可以估算
#             - 虽然仓储分装好后有一个确定的数据,但是从流程优化的角度应该是分拣装载好一辆货车的货物后再进行下一辆车的装载, 因此不应该等到所有门店货物全部装箱完毕后再分配载货货车
#         - 现有物流方案是固定运输线路, 每天满足部分门店需求, 是否可以比较算法选出的运输线路与现有固定线路, 并与熟悉路况的司机探讨, 找出优化线路
